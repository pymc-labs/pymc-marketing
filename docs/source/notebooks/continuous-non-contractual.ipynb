# %% [markdown]
# # Continuous non-Contractual

# %%
import pymmmc

import aesara.tensor as at
import numpy as np
import pandas as pd

from aesara.tensor import TensorVariable

import pymc as pm

import matplotlib.pyplot as plt
import arviz as az

# %% [markdown]
# ### Ground Truth Parameter Values

# %%
rng = np.random.RandomState(seed=34)
T = 10
T0 = 0

# individual-level model
lam = 0.5; p = 0.3

# %% [markdown]
# ### Sampling from the Prior
#
# We will perform inference on the prior data to estimate the values of `lam` and `p` which have been set to 0.5 and 0.3 respectively.

# %%
cnc = pymmmc.ContNonContract.dist(
    lam=lam,
    p=p,
    T=T,
    T0=T0,
)

prior_data = pm.draw(cnc, draws=10000)

# %% [markdown]
# ### Posterior Inference

# %%
with pm.Model() as model:

    λ = pm.Gamma(name="λ", alpha=0.1, beta=0.1)
    π = pm.Beta(name="π", alpha=0.1, beta=0.1)
    
    cnc = pymmmc.ContNonContract(
        name="cnc",
        lam=λ,
        p=π,
        T=T,
        T0=T0,
        observed=prior_data
    )
    
    trace = pm.sample(draws=1000, chains=1, tune=500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [λ, π]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 00:04<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 500 tune and 1_000 draw iterations (500 + 1_000 draws total) took 5 seconds.

# %%
_ = az.plot_posterior(trace, ref_val=[lam, p])
plt.tight_layout()
