# %% [markdown]
# # Interactive MMM Visualizations with `plot_interactive`
#
# This notebook demonstrates the **interactive plotting capabilities** of the
# `plot_interactive` module in `pymc-marketing`. These Plotly-based visualizations
# are designed for exploring MMM results interactively — hovering over data points,
# zooming into time ranges, and faceting across custom dimensions like markets.
#
# We use the **multidimensional MMM** example data (two geos: `geo_a` and `geo_b`,
# two channels: `x1` and `x2`) and fit the model using the same setup as the
# [MMM Multidimensional Example Notebook](https://www.pymc-marketing.io/en/stable/notebooks/mmm/mmm_multidimensional_example.html).
#
# **What this notebook covers:**
#
# - Posterior predictive checks (actual vs predicted)
# - ROAS analysis at different time granularities
# - Channel contributions over time
# - Saturation curves (diminishing returns)
# - Adstock curves (carryover effects)
# - Auto-faceting across custom dimensions
# - Advanced: Filtering and aggregating data with `MMMSummaryFactory` and `MMMPlotlyFactory`

# %%
import warnings

import numpy as np
import pandas as pd
import plotly.io as pio
from pymc_extras.prior import Prior

from pymc_marketing.mmm import GeometricAdstock, LogisticSaturation
from pymc_marketing.mmm.multidimensional import MMM
from pymc_marketing.paths import data_dir
from pymc_marketing.special_priors import LaplacePrior, LogNormalPrior

warnings.filterwarnings("ignore", category=UserWarning)

pio.renderers.default = "notebook_connected"

seed: int = sum(map(ord, "plot_interactive"))
rng: np.random.Generator = np.random.default_rng(seed=seed)

# %% [markdown]
# ## Load Data & Fit Model
#
# We load the same simulated multidimensional dataset used in the
# [MMM Multidimensional Example](https://www.pymc-marketing.io/en/stable/notebooks/mmm/mmm_multidimensional_example.html).
# The data has two geographies (`geo_a`, `geo_b`) and two channels (`x1`, `x2`).
#
# For model fitting details (prior specification, adstock/saturation choices,
# pooling strategies), please refer to the original notebook. Here we set up
# and fit the model quickly so we can focus on **interactive visualizations**.

# %%
data_path = data_dir / "mmm_multidimensional_example.csv"
data_df = pd.read_csv(data_path, parse_dates=["date"])
data_df.head()
# Out:
#         date    geo           x1           x2  event_1  event_2            y
# 0 2022-06-06  geo_a  5527.640078     0.000000        0        0  2647.596355
# 1 2022-06-06  geo_b  8849.257500  8063.918386        0        0   682.406280
# 2 2022-06-13  geo_a  6692.655692     0.000000        0        0  5020.823907
# 3 2022-06-13  geo_b  9073.817994  9354.014585        0        0  3753.104897
# 4 2022-06-20  geo_a  7124.016733     0.000000        0        0  6184.322132

# %%
# --- Prior Specification ---
# Hierarchical beta (partially pooled across geos)
beta_prior = LogNormalPrior(
    mean=Prior("Gamma", mu=0.25, sigma=0.10, dims=("channel")),
    std=Prior("Exponential", scale=0.10, dims=("channel")),
    dims=("channel", "geo"),
    centered=False,
)

# Saturation: beta is hierarchical, lambda is fully pooled
saturation = LogisticSaturation(
    priors={
        "beta": beta_prior,
        "lam": Prior("Gamma", mu=0.5, sigma=0.25, dims=("channel")),
    }
)

# Adstock: unpooled (each geo x channel has its own alpha)
adstock = GeometricAdstock(
    priors={"alpha": Prior("Beta", alpha=2, beta=5, dims=("geo", "channel"))},
    l_max=8,
)

# Model config
model_config = {
    "intercept": Prior("Gamma", mu=0.5, sigma=0.25, dims="geo"),
    "gamma_control": Prior("Normal", mu=0, sigma=0.5, dims="control"),
    "gamma_fourier": LaplacePrior(
        mu=0,
        b=Prior("HalfNormal", sigma=0.2),
        dims=("geo", "fourier_mode"),
        centered=False,
    ),
    "likelihood": Prior(
        "TruncatedNormal",
        lower=0,
        sigma=Prior("HalfNormal", sigma=1.5),
        dims=("date", "geo"),
    ),
}

# --- Model Definition ---
mmm = MMM(
    date_column="date",
    target_column="y",
    channel_columns=["x1", "x2"],
    control_columns=["event_1", "event_2"],
    dims=("geo",),
    scaling={
        "channel": {"method": "max", "dims": ()},
        "target": {"method": "max", "dims": ()},
    },
    adstock=adstock,
    saturation=saturation,
    yearly_seasonality=2,
    model_config=model_config,
)

# --- Fit ---
x_train = data_df.drop(columns=["y"])
y_train = data_df["y"]

mmm.fit(
    X=x_train,
    y=y_train,
    chains=4,
    target_accept=0.95,
    random_seed=rng,
)

# --- Add original scale deterministic variables ---
mmm.build_model(X=x_train, y=y_train)
mmm.add_original_scale_contribution_variable(
    var=[
        "channel_contribution",
        "control_contribution",
        "intercept_contribution",
        "yearly_seasonality_contribution",
        "y",
    ]
)

# --- Posterior predictive ---
mmm.sample_posterior_predictive(X=x_train, random_seed=rng)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [intercept_contribution, adstock_alpha, saturation_lam, saturation_beta_mean, saturation_beta_std, saturation_beta_log_offset, gamma_control, gamma_fourier_b, gamma_fourier_sigma, gamma_fourier_offset, y_sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 16 seconds.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling: [y]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <xarray.Dataset> Size: 20MB
# Dimensions:           (date: 159, geo: 2, sample: 4000)
# Coordinates:
#   * date              (date) datetime64[ns] 1kB 2022-06-06 ... 2025-06-16
#   * geo               (geo) <U5 40B 'geo_a' 'geo_b'
#   * sample            (sample) object 32kB MultiIndex
#   * chain             (sample) int64 32kB 0 0 0 0 0 0 0 0 0 ... 3 3 3 3 3 3 3 3
#   * draw              (sample) int64 32kB 0 1 2 3 4 5 ... 995 996 997 998 999
# Data variables:
#     y                 (date, geo, sample) float64 10MB 0.2945 0.05857 ... 0.2187
#     y_original_scale  (date, geo, sample) float64 10MB 4.068e+03 ... 2.407e+03
# Attributes:
#     created_at:                 2026-02-10T13:45:17.470721+00:00
#     arviz_version:              0.23.4
#     inference_library:          pymc
#     inference_library_version:  5.27.1

# %% [markdown]
# ---
#
# ## 1. Posterior Predictive: How Well Does the Model Fit?
#
# The posterior predictive plot shows the model's predictions (with uncertainty)
# against the observed data. This is the first thing to check after fitting —
# do the predictions track the actual sales?
#
# The interactive plot lets you **hover** over any point to see exact values,
# and **zoom** into specific time periods.

# %%
mmm.plot_interactive.posterior_predictive()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1cbf1365-e7ab-495d-899e-1eb92306220e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1cbf1365-e7ab-495d-899e-1eb92306220e")) {                    Plotly.newPlot(                        "1cbf1365-e7ab-495d-899e-1eb92306220e",                        [{"customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"=Predicted\u003cbr\u003eDate=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Predicted","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Predicted","orientation":"v","showlegend":true,"x":["2022-06-06T00:00:00.000000000","2022-06-13T00:00:00.000000000","2022-06-20T00:00:00.000000000","2022-06-27T00:00:00.000000000","2022-07-04T00:00:00.000000000","2022-07-11T00:00:00.000000000","2022-07-18T00:00:00.000000000","2022-07-25T00:00:00.000000000","2022-08-01T00:00:00.000000000","2022-08-08T00:00:00.000000000","2022-08-15T00:00:00.000000000","2022-08-22T00:00:00.000000000","2022-08-29T00:00:00.000000000","2022-09-05T00:00:00.000000000","2022-09-12T00:00:00.000000000","2022-09-19T00:00:00.000000000","2022-09-26T00:00:00.000000000","2022-10-03T00:00:00.000000000","2022-10-10T00:00:00.000000000","2022-10-17T00:00:00.000000000","2022-10-24T00:00:00.000000000","2022-10-31T00:00:00.000000000","2022-11-07T00:00:00.000000000","2022-11-14T00:00:00.000000000","2022-11-21T00:00:00.000000000","2022-11-28T00:00:00.000000000","2022-12-05T00:00:00.000000000","2022-12-12T00:00:00.000000000","2022-12-19T00:00:00.000000000","2022-12-26T00:00:00.000000000","2023-01-02T00:00:00.000000000","2023-01-09T00:00:00.000000000","2023-01-16T00:00:00.000000000","2023-01-23T00:00:00.000000000","2023-01-30T00:00:00.000000000","2023-02-06T00:00:00.000000000","2023-02-13T00:00:00.000000000","2023-02-20T00:00:00.000000000","2023-02-27T00:00:00.000000000","2023-03-06T00:00:00.000000000","2023-03-13T00:00:00.000000000","2023-03-20T00:00:00.000000000","2023-03-27T00:00:00.000000000","2023-04-03T00:00:00.000000000","2023-04-10T00:00:00.000000000","2023-04-17T00:00:00.000000000","2023-0 ...

# %% [markdown]
# ---
#
# ## 2. ROAS Analysis: Which Channels Give the Best Return?
#
# ROAS (Return on Ad Spend) is one of the most important metrics for marketers.
# The `plot_interactive` module makes it easy to slice and dice ROAS across
# different time granularities and dimensions.
#
# ### Q: How did the ROAS of each channel change year after year?

# %%
mmm.plot_interactive.roas(
    frequency="yearly",
    color="date",
    x="channel",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="f9f86657-2ade-4aa6-a964-c367d16e2ee0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f9f86657-2ade-4aa6-a964-c367d16e2ee0")) {                    Plotly.newPlot(                        "f9f86657-2ade-4aa6-a964-c367d16e2ee0",                        [{"alignmentgroup":"True","customdata":[["0.064 HDI: [0.0, 0.135]","geo_a"],["nan HDI: [nan, nan]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"pn58gq8bsj\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002ffw=="},"arrayminus":{"dtype":"f8","bdata":"YiZrtORIsD8AAAAAAAD4fw=="}},"hovertemplate":"date=2022\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2022","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2022","offsetgroup":"2022","orientation":"v","showlegend":true,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"5Hj8E5NgsD8AAAAAAAD4fw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.066 HDI: [0.002, 0.142]","geo_b"],["0.05 HDI: [0.0, 0.103]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"8MJuGA9ssz+bHLLPFxGrPw=="},"arrayminus":{"dtype":"f8","bdata":"EtFEl1COsD9FaOG3\u002f6upPw=="}},"hovertemplate":"date=2022\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2022","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2022","offsetgroup":"2022","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ymy10Av5sD+FSn52vrKpPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["0.064 HDI: [0.0, 0.136]","geo_a"],["0.074 HDI: [0.001, 0.152]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"v60QC40\u002fsj8GUp4Ine6zPw=="},"arrayminus":{"dtype":"f8","bdata":"FApnOk5fsD85V2yzUqyyPw=="}},"hovertemplate":"date=2023\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2023","offsetgroup":"2023","orientation":"v","showlegend":true,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"L13tVGp8sD90pv0Z1AizPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.066 HDI: [0.002, 0.142]","geo_b"],["0.05 HDI: [0.0, 0.104]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"Maw28Ldusz9CHLWJnFKrPw=="},"arrayminus":{"dtype":"f8","bdata":"xWDPyG1esD+1tvE9aJepPw=="}},"hovertemplate":"date=2023\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2023","offsetgroup":"2023","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"aVz1S7HfsD+kAqA07capPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["0.067 HDI: [0.001, 0.141]","geo_a"],["0.074 HDI: [0.001, 0.152]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"dAeT0xvxsj8qLPC\u002ftPGzPw=="},"arrayminus":{"dtype":"f8","bdata":"XhVfEJ7rsD+S\u002ff9wqKeyPw=="}},"hovertemplate":"date=2024\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2024","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"2024","offsetgroup":"2024","orientation":"v","showlegend":true,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"buvP0gANsT+o6RxBqgazPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.067 HDI: [0.002, 0.145]","geo_b"],["0.05 HDI: [0.0, 0.104]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"aPq7Gv3Gsz+ILboxV02rPw=="}," ...

# %% [markdown]
# ### Q: Within each year, which channel performed better in each geo?
#
# By swapping `x` and `color`, we get a different perspective — now the x-axis
# shows time and the color differentiates channels.

# %%
mmm.plot_interactive.roas(
    frequency="yearly",
    color="channel",
    x="date",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="84e2ee2c-8aa5-4a87-adea-77f96e448b69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("84e2ee2c-8aa5-4a87-adea-77f96e448b69")) {                    Plotly.newPlot(                        "84e2ee2c-8aa5-4a87-adea-77f96e448b69",                        [{"alignmentgroup":"True","customdata":[["0.064 HDI: [0.0, 0.135]","geo_a"],["0.064 HDI: [0.0, 0.136]","geo_a"],["0.067 HDI: [0.001, 0.141]","geo_a"],["0.065 HDI: [0.0, 0.136]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"pn58gq8bsj+\u002frRALjT+yP3QHk9Mb8bI\u002fuEFp5aFHsj8="},"arrayminus":{"dtype":"f8","bdata":"YiZrtORIsD8UCmc6Tl+wP14VXxCe67A\u002f1iDBBvF+sD8="}},"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"5Hj8E5NgsD8vXe1UanywP27rz9IADbE\u002fJHTJMxOcsD8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.066 HDI: [0.002, 0.142]","geo_b"],["0.066 HDI: [0.002, 0.142]","geo_b"],["0.067 HDI: [0.002, 0.145]","geo_b"],["0.067 HDI: [0.002, 0.143]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"8MJuGA9ssz8xrDbwt26zP2j6uxr9xrM\u002fZrB2ja18sz8="},"arrayminus":{"dtype":"f8","bdata":"EtFEl1COsD\u002fFYM\u002fIbV6wP5KqQ++owrA\u002fzWtprtGosD8="}},"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ymy10Av5sD9pXPVLsd+wP2SUSOA2R7E\u002foH5RaZ8XsT8="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["nan HDI: [nan, nan]","geo_a"],["0.074 HDI: [0.001, 0.152]","geo_a"],["0.074 HDI: [0.001, 0.152]","geo_a"],["0.07 HDI: [0.001, 0.144]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f38GUp4Ine6zPyos8L+08bM\u002fpv2yFmUDsz8="},"arrayminus":{"dtype":"f8","bdata":"AAAAAAAA+H85V2yzUqyyP5L9\u002f3Cop7I\u002fcU\u002fX0WW2sT8="}},"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H90pv0Z1AizP6jpHEGqBrM\u002fDtM1qlTqsT8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.05 HDI: [0.0, 0.103]","geo_b"],["0.05 HDI: [0.0, 0.104]","geo_b"],["0.05 HDI: [0.0, 0.104]","geo_b"],["0.045 HDI: [0.0, 0.094]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"mxyyzxcRqz9CHLWJnFKrP4gtujFXTas\u002fZ4+eRh5CqT8="},"arrayminus":{"dtype":"f8","bdata":"RWjht\u002f+rqT+1tvE9aJepP+rrZAFzjqk\u002ffLX9toqUpj8="}},"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"hUp+dr6yqT+kAqA07capP75eohD3vak\u002f3RC24XXJpj8="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0 ...

# %% [markdown]
# ### Q: Looking over all the data, which channel performed better in each geo?
#
# Using `frequency="all_time"` aggregates everything into a single time period,
# giving us the overall ROAS per channel per geo.

# %%
mmm.plot_interactive.roas(frequency="all_time")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="461c0b66-1384-45bb-9ba7-66579f6af189" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("461c0b66-1384-45bb-9ba7-66579f6af189")) {                    Plotly.newPlot(                        "461c0b66-1384-45bb-9ba7-66579f6af189",                        [{"alignmentgroup":"True","customdata":[["0.065 HDI: [0.0, 0.137]","geo_a"],["0.074 HDI: [0.001, 0.15]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"mZe8TJ1Xsj95ZH8dWI+zPw=="},"arrayminus":{"dtype":"f8","bdata":"HeIGm6WKsD9ZYFbTzbmyPw=="}},"hovertemplate":"ROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"f4hs69KisD\u002fjchp4U+OyPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.067 HDI: [0.002, 0.143]","geo_b"],["0.05 HDI: [0.0, 0.103]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"YmewEAF0sz8c1kC7rSWrPw=="},"arrayminus":{"dtype":"f8","bdata":"kQZ5WZKIsD+S1VUgllypPw=="}},"hovertemplate":"ROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ikYttxgLsT8ajaTM7IupPw=="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overla ...

# %% [markdown]
# ---
#
# ## 3. Channel Contributions: What Drives Sales?
#
# The contributions plot shows how much each channel contributes to total sales
# over time. It supports the same `frequency`, `color`, and `x` parameters as
# `roas()` above, so you can slice contributions in exactly the same way —
# by time granularity, channel, or geography.
#
# ### Q: What is the overall contribution of each channel across all geos?
#
# Error bars show the 94% HDI (Highest Density Interval).

# %%
mmm.plot_interactive.contributions(frequency="all_time")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="11f46afc-bebf-4c03-abb1-aad3b06e25ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("11f46afc-bebf-4c03-abb1-aad3b06e25ac")) {                    Plotly.newPlot(                        "11f46afc-bebf-4c03-abb1-aad3b06e25ac",                        [{"alignmentgroup":"True","customdata":[["38499 HDI: [219, 80947]","geo_a"],["32259 HDI: [277, 65666]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"NfVqpfe55EDYqUjn3k\u002fgQA=="},"arrayminus":{"dtype":"f8","bdata":"9MnM4hSx4kAtJz39kzvfQA=="}},"hovertemplate":"Contribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"9T2ZtWbM4kCxIqgn1YDfQA=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["50214 HDI: [1502, 107529]","geo_b"],["23509 HDI: [170, 48491]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"HTShL0r860CB\u002fg2bimXYQA=="},"arrayminus":{"dtype":"f8","bdata":"8btCaQbJ50DUe0\u002fzwsrWQA=="}},"hovertemplate":"Contribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"z2ZMscyE6EBPVVXETfXWQA=="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpa ...

# %% [markdown]
# ### Q: How did channel contributions change year by year?
#
# Just like the ROAS examples, setting `frequency="yearly"`, `color="channel"`,
# and `x="date"` gives us a time-series view colored by channel.

# %%
mmm.plot_interactive.contributions(
    frequency="yearly",
    color="channel",
    x="date",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="6db4649d-1c00-45ee-a821-71c999859bf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6db4649d-1c00-45ee-a821-71c999859bf4")) {                    Plotly.newPlot(                        "6db4649d-1c00-45ee-a821-71c999859bf4",                        [{"alignmentgroup":"True","customdata":[["8503 HDI: [48, 17904]","geo_a"],["14758 HDI: [102, 31094]","geo_a"],["11302 HDI: [86, 23857]","geo_a"],["3937 HDI: [27, 8270]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"GaV8uKpcwkBcr5QByefPQADvpzF\u002fhchAi\u002f2t\u002fcbssEA="},"arrayminus":{"dtype":"f8","bdata":"VPCV01SDwEBuS0KXHqDMQLNpddWR58VAbByBcd+LrkA="}},"hovertemplate":"channel=x1\u003cbr\u003eContribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"z7EMLlibwEDQUeDrA9PMQLK8IDDKEsZAXt5cMdLBrkA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["11396 HDI: [280, 24437]","geo_b"],["18440 HDI: [552, 39676]","geo_b"],["16245 HDI: [487, 34839]","geo_b"],["4133 HDI: [105, 8846]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"mTpvL2B4yUDut87Z\u002fLzUQPPw3IekKNJAFibcJ5xoskA="},"arrayminus":{"dtype":"f8","bdata":"VcAPGyS2xUCD3zOx\u002f3fRQIaViTMKx85AgN5uCZ55r0A="}},"hovertemplate":"channel=x1\u003cbr\u003eContribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"bfn74BtCxkDsQ\u002fG98gHSQH6hveVzus9AvPAqBXslsEA="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["0 HDI: [0, 0]","geo_a"],["14043 HDI: [267, 28749]","geo_a"],["14312 HDI: [279, 29315]","geo_a"],["3904 HDI: [44, 8046]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"AAAAAAAAAACYLC9E2bjMQF1X+ViCTc1Au7UUarwusEA="},"arrayminus":{"dtype":"f8","bdata":"AAAAAAAAAADQNF7rbejKQDrcgdeWaMtAXNGujqEmrkA="}},"hovertemplate":"channel=x2\u003cbr\u003eContribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAADiHd+8um3LQNHhD24t9MtARBaFkQh\u002frkA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2086 HDI: [2, 4283]","geo_b"],["9637 HDI: [69, 19851]","geo_b"],["10326 HDI: [74, 21278]","geo_b"],["1461 HDI: [13, 3079]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"Wwpl3D0qoUC7CrJVRvPDQN3JHlrbY8VA6csFj8pLmUA="},"arrayminus":{"dtype":"f8","bdata":"knomRchHoEAzM7i3qK\u002fCQAQBGXG8BcRAxYKGcjCdlkA="}},"hovertemplate":"channel=x2\u003cbr\u003eContribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"u6gLUw9MoEDBFB8+W9LCQFHbnnn2KsRAqYJO4S\u002fSlkA="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9 ...

# %% [markdown]
# ### Q: How did the contributions of control variables change year by year?
#
# On top of channel contributions, we can also plot the contributions of control, seasonality, and baseline variables.

# %%
mmm.plot_interactive.contributions(
    component="control",
    frequency="yearly",
    color="control",
    x="date",
    hdi_prob=None,
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d5f9c442-1178-4991-b0d3-9fc0cb0bbc89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d5f9c442-1178-4991-b0d3-9fc0cb0bbc89")) {                    Plotly.newPlot(                        "d5f9c442-1178-4991-b0d3-9fc0cb0bbc89",                        [{"alignmentgroup":"True","customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"control=event_1\u003cbr\u003eContribution=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"event_1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"event_1","offsetgroup":"event_1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"KKyp9DmAsEAorKn0OYDAQAAAAAAAAAAAAAAAAAAAAAA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_b"],["geo_b"],["geo_b"],["geo_b"]],"hovertemplate":"control=event_1\u003cbr\u003eContribution=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"event_1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"event_1","offsetgroup":"event_1","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"eFeu0DRKqkB4V67QNEq6QAAAAAAAAAAAAAAAAAAAAAA="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"control=event_2\u003cbr\u003eContribution=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"event_2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"event_2","offsetgroup":"event_2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACgHkdkaMGkwKAeR2RowZTAAAAAAAAAAAA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_b"],["geo_b"],["geo_b"],["geo_b"]],"hovertemplate":"control=event_2\u003cbr\u003eContribution=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"event_2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"event_2","offsetgroup":"event_2","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAAAD3BAVOxIigwPcEBU7EiJDAAAAAAAAAAAA="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"con ...

# %% [markdown]
# ---
#
# ## 4. Saturation Curves: Where Are Diminishing Returns?
#
# Saturation curves show how the response (contribution) changes as spend
# increases. These are essential for understanding where additional spend
# will have diminishing returns.
#
# ### Q: Show me the saturation curves in original scale
#
# By default, the x-axis is in original scale (e.g., dollars of spend).
# Each channel gets its own line, faceted by geo.

# %%
mmm.plot_interactive.saturation_curves()
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="c687259b-8327-49c5-8020-45ae0192976f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c687259b-8327-49c5-8020-45ae0192976f")) {                    Plotly.newPlot(                        "c687259b-8327-49c5-8020-45ae0192976f",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAB+MqffY4hXQH4yp99jiGdA3mW950qmcUB+MqffY4h3QB7\u002fkNd8an1A3mW950qmgUAvTLJjV5eEQH4yp99jiIdAzRicW3B5ikAe\u002f5DXfGqNQLfywqnELZBA3mW950qmkUAG2bcl0R6TQC9MsmNXl5RAVr+sod0PlkB+MqffY4iXQKaloR3qAJlAzRicW3B5mkD2i5aZ9vGbQB7\u002fkNd8ap1ARXKLFQPjnkC38sKpxC2gQEsswMgH6qBA3mW950qmoUByn7oGjmKiQAbZtyXRHqNAmxK1RBTbo0AvTLJjV5ekQMKFr4KaU6VAVr+sod0PpkDq+KnAIMymQH4yp99jiKdAEmyk\u002fqZEqECmpaEd6gCpQDrfnjwtvalAzRicW3B5qkBhUpl6szWrQPaLlpn28atAisWTuDmurEAe\u002f5DXfGqtQLI4jva\u002fJq5ARXKLFQPjrkDZq4g0Rp+vQLfywqnELbBAgY9BOeaLsEBLLMDIB+qwQBXJPlgpSLFA3mW950qmsUCoAjx3bASyQHKfugaOYrJAPTw5lq\u002fAskAG2bcl0R6zQNB1NrXyfLNAmxK1RBTbs0BkrzPUNTm0QC9MsmNXl7RA+Ogw83j1tEDCha+CmlO1QIwiLhK8sbVAVr+sod0PtkAgXCsx\u002f222QOr4qcAgzLZAtJUoUEIqt0B+MqffY4i3QEfPJW+F5rdAEmyk\u002fqZEuEDcCCOOyKK4QKaloR3qALlAcEIgrQtfuUA63548Lb25QAR8HcxOG7pAzRicW3B5ukCYtRrrkde6QGFSmXqzNbtALO8XCtWTu0D2i5aZ9vG7QL8oFSkYULxAisWTuDmuvEBTYhJIWwy9QB7\u002fkNd8ar1A55sPZ57IvUCyOI72vya+QHvVDIbhhL5ARXKLFQPjvkAPDwqlJEG\u002fQNmriDRGn79ApEgHxGf9v0C38sKpxC3AQBxBgnHVXMBAgY9BOeaLwEDl3QAB97rAQEsswMgH6sBAr3p\u002fkBgZwUAVyT5YKUjBQHkX\u002fh86d8FA3mW950qmwUBEtHyvW9XBQKgCPHdsBMJADVH7Pn0zwkA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA
u002f5neUAHO1VUJch5QMU5eycxKHpAL\u002fxf9CGIekBnOzdn9+d6QL9b5iyxR3tADn8F806ne0A2iuBn0AZ8QK4feDo1ZnxAD42CGn3FfEBxrWy4pyR9QJe\u002fWsW0g31ApTAp86PifUA4W230dEF+QIE6dnwnoH5APBNNP7v+fkC5D7bxL11\u002fQEjSMEmFu39Axn38fd0MgEBNU4Ng6DuAQO5sByjjaoBA3PbBsM2ZgEAY9ErXp8iAQHNnmXhx94BA\u002fnYDciomgUDmij6h0lSBQPpmX+Rpg4FAhT\u002faGfCxgUAtyYIgZeCBQFREjNfIDoJAZIOJHhs9gkD07GzVW2uCQAl5iNyKmYJAQaqNFKjHgkA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002f6ukTjpq9ARWxtkg8+sEBbW32CraiwQHBKjXJLE7FAhTmdYul9sUCbKK1Sh+ixQLAXvUIlU7JAxgbNMsO9skDb9dwiYSizQPHk7BL\u002fkrNABtT8Ap39s0AcwwzzOmi0QDGyHOPY0rRAR6Es03Y9tUBckDzDFKi1QHF\u002fTLOyErZAh25co1B9tkCcXWyT7ue2QLJMfIOMUrdAxzuMcyq9t0DcKpxjyCe4QPMZrFNmkrhABwm8QwT9uEAe+Mszome5QDPn2yNA0rlASdbrE948ukBexfsDfKe6QHO0C\u002fQZErtAiaMb5Ld8u0CekivUVee7QLSBO8TzUbxAyXBLtJG8vEDfX1ukLye9QPROa5TNkb1ACT57hGv8vUAfLYt0CWe+QDQ ...

# %% [markdown]
# ---
#
# ## 5. Adstock Curves: How Long Do Effects Last?
#
# Adstock (carryover) curves show how the effect of a marketing impulse
# decays over time. A slow decay means the channel has long-lasting effects;
# a fast decay means the effect is short-lived.
#
# ### Q: How do the decay curves look?

# %%
mmm.plot_interactive.adstock_curves(hdi_prob=None)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="568b28ba-33df-41d0-b2d8-1812f7a6e0e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("568b28ba-33df-41d0-b2d8-1812f7a6e0e6")) {                    Plotly.newPlot(                        "568b28ba-33df-41d0-b2d8-1812f7a6e0e6",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"SXLllVEt5j\u002fbqhIoHuDHP6fBUqWLBLE\u002ft1+sAmOlnD8cSotVHRCLPx5qtq7t5ns\u002fJZor+rzUbj8ENGKoRQdiPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"hJCIahlP5z+SNZ2BxNnGP3aPtB+fxqw\u002fY3jdne1olT8qahKS8QGCP3Ok4bWVp3A\u002fl8lnQlCdYD86QfFeqJ9RPw=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"ycZTBYY95j89EYMlWKbHP9r7rjlev7A\u002f\u002fnMznnFunD\u002fFdrdeznWLPxmZjT6dLH0\u002fCxS7mqKkcD8nm4r24wpkPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"L+2og9VE5z+S6jb6KXzGP9WVdP\u002f82Kw\u002fWZfAcKyAlj+wvJvZ0DCEPxuL2u4CD3Q\u002f1GP8Zjd8ZT\u002fGTdNBk1pYPw=="},"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdc ...

# %% [markdown]
# ### Q: Show me adstock curves with uncertainty
#
# Adding HDI bands helps us understand how confident we are about the
# carryover duration for each channel.

# %%
mmm.plot_interactive.adstock_curves(hdi_prob=0.9)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="6d28161f-647d-422c-9b79-f0316a39c96b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6d28161f-647d-422c-9b79-f0316a39c96b")) {                    Plotly.newPlot(                        "6d28161f-647d-422c-9b79-f0316a39c96b",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"19DhnguZ5j99hB4mqG\u002fHPxT3fuPUDbA\u002fcnrmVMcvmj8\u002f5m7LNAeIP17boZQW\u002fXc\u002fWsKu2JqAaT8TiJqfynNcPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"FjFTJJ5M5z\u002fzH5uwRrXGP33HiZ6d8aw\u002fTy78aunZlT\u002fNSMDDlqCCPzLKueDnaXE\u002ftWWUAgWAYT+O2P\u002fktKFSPw=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"3XotUR\u002fg5T8LwbBMLYDIP0UuksBplLE\u002foYkbd5u0nT+K0Ecxwj6MP5Ly1Vr8W30\u002f8deYRrFZcD8c+DXT4zxjPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"gdlXV8JO5z8opB5JRTLGP1D2Kv9kzKw\u002fPmLpXV7Mlj\u002fOVnFzhsqEP52J1pPnBnU\u002fLoGxibf5Zj94Ib7+5aJaPw=="},"yaxis":"y2","type":"scatter"},{"fill":"toself","fillcolor":"rgba(99.0,110.0,250.0,0.2)","hoverinfo":"none","line":{"color":"rgba(255,255,255,0)"},"mode":"lines","name":"x1 HDI","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgcHBgUEAwIBAA=="},"y":{"dtype":"f8","bdata":"CDaoAJSb2j9OqxrK5LGwPyuKD\u002fkTvHI\u002fvp8EAEwGNT+DfsaHbJj3PgxQGo9Ne7o+DjKWDt64fT63jqMyI65APpc5qCrASYU\u002fNeocWl8Hkj\u002frl\u002fhfe4meP6rUIF6Y3Kk\u002f8Sgz4\u002fTmtT+yceSVgozCPybDUEJICtA\u002fkYRqtXfB7T8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","fillcolor":"rgba(239.0,85.0,59.0,0.2)","hoverinfo":"none","line":{"color":"rgba(255,255,255,0)"},"mode":"lines","name":"x2 HDI","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgcHBgUEAwIBAA=="},"y":{"dtype":"f8","bdata":"SRaPI8aP2T8ldMCSnZezPwPJiXVbLXo\u002fzhwJHuF8QT8XFOUQql0HP2EKNfdQOM8+WWx1YXXblD4qZHzJXt5bPji9Pt0oJIk\u002fsfExU1OslD+i7PBtxv+gP1V3mr3C9Ks\u002fepFuJ978tj\u002fl6MwpBOfCP2EyUQT3CtA\u002fz\u002f\u002ftZOxT7T8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","fillcolor":"rgba(99.0,110.0,250.0,0.2)","hoverinfo":"none","line":{"color":"rgba(255,255,255,0)"},"mode":"lines","name":"x1 HDI","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgcHBgUEAwIB ...

# %% [markdown]
# ---
#
# ## 6. Auto-faceting Across Custom Dimensions
#
# When your model includes **custom dimensions** (like `geo` in our example),
# `plot_interactive` **automatically creates subplots** (facets) for each
# dimension value. You've already seen this in all the plots above — each
# subplot corresponds to a different geography (`geo_a` and `geo_b`).
#
# This behavior is controlled by the `auto_facet` parameter, which is
# **enabled by default**. You can also control the faceting layout with
# `facet_col` and `facet_row`:
#
# - `facet_col` — creates side-by-side columns (one per dimension value)
# - `facet_row` — stacks subplots vertically (one per dimension value)
# - `single_dim_facet` — controls the default direction (`"col"` or `"row"`)
#
# ### Q: Compare saturation curves across geos stacked vertically
#
# Using `facet_row="geo"` overrides the default column layout and stacks
# the saturation curves vertically instead.

# %%
mmm.plot_interactive.saturation_curves(
    facet_row="geo",
)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ac65a4c8-42f9-4ccb-ad1e-ddccd8c23bc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ac65a4c8-42f9-4ccb-ad1e-ddccd8c23bc1")) {                    Plotly.newPlot(                        "ac65a4c8-42f9-4ccb-ad1e-ddccd8c23bc1",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAB+MqffY4hXQH4yp99jiGdA3mW950qmcUB+MqffY4h3QB7\u002fkNd8an1A3mW950qmgUAvTLJjV5eEQH4yp99jiIdAzRicW3B5ikAe\u002f5DXfGqNQLfywqnELZBA3mW950qmkUAG2bcl0R6TQC9MsmNXl5RAVr+sod0PlkB+MqffY4iXQKaloR3qAJlAzRicW3B5mkD2i5aZ9vGbQB7\u002fkNd8ap1ARXKLFQPjnkC38sKpxC2gQEsswMgH6qBA3mW950qmoUByn7oGjmKiQAbZtyXRHqNAmxK1RBTbo0AvTLJjV5ekQMKFr4KaU6VAVr+sod0PpkDq+KnAIMymQH4yp99jiKdAEmyk\u002fqZEqECmpaEd6gCpQDrfnjwtvalAzRicW3B5qkBhUpl6szWrQPaLlpn28atAisWTuDmurEAe\u002f5DXfGqtQLI4jva\u002fJq5ARXKLFQPjrkDZq4g0Rp+vQLfywqnELbBAgY9BOeaLsEBLLMDIB+qwQBXJPlgpSLFA3mW950qmsUCoAjx3bASyQHKfugaOYrJAPTw5lq\u002fAskAG2bcl0R6zQNB1NrXyfLNAmxK1RBTbs0BkrzPUNTm0QC9MsmNXl7RA+Ogw83j1tEDCha+CmlO1QIwiLhK8sbVAVr+sod0PtkAgXCsx\u002f222QOr4qcAgzLZAtJUoUEIqt0B+MqffY4i3QEfPJW+F5rdAEmyk\u002fqZEuEDcCCOOyKK4QKaloR3qALlAcEIgrQtfuUA63548Lb25QAR8HcxOG7pAzRicW3B5ukCYtRrrkde6QGFSmXqzNbtALO8XCtWTu0D2i5aZ9vG7QL8oFSkYULxAisWTuDmuvEBTYhJIWwy9QB7\u002fkNd8ar1A55sPZ57IvUCyOI72vya+QHvVDIbhhL5ARXKLFQPjvkAPDwqlJEG\u002fQNmriDRGn79ApEgHxGf9v0C38sKpxC3AQBxBgnHVXMBAgY9BOeaLwEDl3QAB97rAQEsswMgH6sBAr3p\u002fkBgZwUAVyT5YKUjBQHkX\u002fh86d8FA3mW950qmwUBEtHyvW9XBQKgCPHdsBMJADVH7Pn0zwkA="},"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAAADmecScWYIZQL+qsBVLgilAVVCnJ6YhM0C02sb6EII5QKpfEsJe4j9AeaspHkQhQ0D+S74UQ1FGQLPGcqUogUlAI6HCMfGwTEBaoRYcmeBPQH0S8WMOiFFACy7gTLwfU0Awssh7VLdUQJKgSyTVTlZAv1fJejzmV0BL6G+0iH1ZQGZUSQe4FFtAhbhJqsirXEBsW13VuEJeQPqjdsGG2V9AMPpNVBi4YEDIs\u002fpiWoNhQBE57aqITmJAG7HvSqIZY0BfYHFipuRjQKtHjRGUr2RAFLIQeWp6ZUCwsIG6KEVmQKeDJfjND2dABPAGVVnaZ0Awgvz0yaRoQIy7rvweb2lAyCuekVc5akAHdSnacgNrQOY5k\u002f1vzWtA5fUHJE6XbEDlvqN2DGFtQOLvdx+qKm5A8LuQSSb0bkB7qvoggL1vQO78Y
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="bbb07651-4b59-42e2-9565-ade838a76891" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bbb07651-4b59-42e2-9565-ade838a76891")) {                    Plotly.newPlot(                        "bbb07651-4b59-42e2-9565-ade838a76891",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"fjb\u002fylhO5j+JHViwLZDHPw9RfKjdhLA\u002fbyGdU8T+mz+WOBQjViCLP7OkHc70Dn0\u002f8o7pI6zUcD+Gru\u002fNVsFkPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"R5WdfNcd6D97sj5lPCjFP3G3oPADWak\u002fDrK8Yghukj\u002f\u002fIQvULrF+P3co9j+5Qmw\u002fvsy03rMXXD\u002fx8Zht3J9NPw=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"9CTENKYc5j9EPdYPuerHP3NLQTFcB7E\u002f+Vywr37onD\u002f5zUiUpduLPxYAlbdbhn0\u002fg7aV85PVcD+bvSb5lVVkPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"HBZR6EAx5z8r+rppvJDGP7DrpszjJq0\u002fyUGhvN37lj\u002fWuyFDbNWEP2VOHg5S2nQ\u002fLv47e+9yZj+qDmbZG4tZPw=="},"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %% [markdown]
# ---
#
# ## 7. Advanced: Filtering & Aggregating with the Data Layer
#
# > **This is an advanced section.** The examples above cover the most common
# > use cases through `mmm.plot_interactive`. This section shows how to work
# > directly with the underlying components for custom data slicing.
#
# Under the hood, `mmm.plot_interactive` is powered by two key classes:
#
# - **`MMMSummaryFactory`** — Takes a data wrapper (from `mmm.data`) and the
#   fitted model, and computes summary statistics like contributions, ROAS,
#   and posterior predictive values. It handles HDI computation, time
#   aggregation, and proper scaling. You can think of it as the "data engine"
#   that turns raw InferenceData into plottable DataFrames.
#
# - **`MMMPlotlyFactory`** — Takes an `MMMSummaryFactory` and provides all
#   the interactive plotting methods (`posterior_predictive()`, `roas()`,
#   `contributions()`, `saturation_curves()`, `adstock_curves()`). It reads
#   from the summary factory and creates Plotly figures.
#
# When you call `mmm.plot_interactive`, it automatically creates both of
# these using your full dataset. But you can also create them **manually**
# with filtered or aggregated data — this is the key to custom views.
#
# The workflow is:
#
# 1. **Transform the data** using `mmm.data.filter_dims()`, `mmm.data.filter_dates()`,
#    or `mmm.data.aggregate_dims()`
# 2. **Create a new `MMMSummaryFactory`** with the transformed data
# 3. **Create a new `MMMPlotlyFactory`** with that summary
# 4. **Plot** using the factory's methods
#
# ### Q: Aggregating over geos, how did the ROAS of each channel change year after year?
#
# Here we aggregate both geos into a single "all_geos" label, then plot ROAS.
# This collapses the geo dimension so we get a single aggregated view.

# %%
from pymc_marketing.mmm.plot_interactive import MMMPlotlyFactory
from pymc_marketing.mmm.summary import MMMSummaryFactory

# Aggregate geo_a and geo_b into "all_geos"
agg_data = mmm.data.aggregate_dims(
    dim="geo", values=["geo_a", "geo_b"], new_label="all_geos"
)
agg_summary = MMMSummaryFactory(agg_data, mmm)
agg_factory = MMMPlotlyFactory(summary=agg_summary)

agg_factory.roas(
    frequency="yearly",
    color="channel",
    x="date",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="3bcd87d3-1646-45ac-8a1c-659edd21890a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3bcd87d3-1646-45ac-8a1c-659edd21890a")) {                    Plotly.newPlot(                        "3bcd87d3-1646-45ac-8a1c-659edd21890a",                        [{"alignmentgroup":"True","customdata":[["0.134 HDI: [0.007, 0.263]","all_geos"],["0.134 HDI: [0.01, 0.263]","all_geos"],["0.139 HDI: [0.01, 0.273]","all_geos"],["0.134 HDI: [0.01, 0.261]","all_geos"]],"error_y":{"array":{"dtype":"f8","bdata":"1bjz7v5mwD+8GJAZmYDAP3P1iZ3MMcE\u002fj5XOzUFBwD8="},"arrayminus":{"dtype":"f8","bdata":"UoFZYs9AwD8HRI5llbC\u002fPxK4pTTniMA\u002fTVp+uQ2Wvz8="}},"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"q58KK3E1wT\u002fmBpk52SDBP1WDLLzGwsE\u002fmUwde4YewT8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.113 HDI: [0.0, 0.232]","all_geos"],["0.123 HDI: [0.012, 0.248]","all_geos"],["0.123 HDI: [0.012, 0.247]","all_geos"],["0.116 HDI: [0.013, 0.238]","all_geos"]],"error_y":{"array":{"dtype":"f8","bdata":"\u002fGKkwJqFvj8Bu+qzV+m\u002fP7h6jJBYzr8\u002fmHtqUSMivz8="},"arrayminus":{"dtype":"f8","bdata":"424OOu3yvD8nq9kjSZG8P0L5m5rOZrw\u002fJOQ2Saxouj8="}},"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"3ta7ZIj6vD8x0e6\u002fk52\u002fP3TiaRC8hb8\u002fPir\u002fkVnIvT8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","col ...

# %% [markdown]
# ### Q: Filtering to only one geo, what was the yearly ROAS?
#
# You can filter the data to a single geography and create a dedicated factory.

# %%
filtered_data_geo_a = mmm.data.filter_dims(geo="geo_a")
filtered_summary_geo_a = MMMSummaryFactory(
    filtered_data_geo_a, mmm, validate_data=False
)
filtered_factory_geo_a = MMMPlotlyFactory(summary=filtered_summary_geo_a)

filtered_factory_geo_a.roas(
    frequency="yearly",
    color="channel",
    x="date",
    title="ROAS for geo_a (yearly)",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="df752302-1c67-4227-a351-878af9044bd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("df752302-1c67-4227-a351-878af9044bd2")) {                    Plotly.newPlot(                        "df752302-1c67-4227-a351-878af9044bd2",                        [{"alignmentgroup":"True","customdata":[["0.064 HDI: [0.0, 0.135]"],["0.064 HDI: [0.0, 0.136]"],["0.067 HDI: [0.001, 0.141]"],["0.065 HDI: [0.0, 0.136]"]],"error_y":{"array":{"dtype":"f8","bdata":"pn58gq8bsj+\u002frRALjT+yP3QHk9Mb8bI\u002fuEFp5aFHsj8="},"arrayminus":{"dtype":"f8","bdata":"YiZrtORIsD8UCmc6Tl+wP14VXxCe67A\u002f1iDBBvF+sD8="}},"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"5Hj8E5NgsD8vXe1UanywP27rz9IADbE\u002fJHTJMxOcsD8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["nan HDI: [nan, nan]"],["0.074 HDI: [0.001, 0.152]"],["0.074 HDI: [0.001, 0.152]"],["0.07 HDI: [0.001, 0.144]"]],"error_y":{"array":{"dtype":"f8","bdata":"\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f38GUp4Ine6zPyos8L+08bM\u002fpv2yFmUDsz8="},"arrayminus":{"dtype":"f8","bdata":"AAAAAAAA+H85V2yzUqyyP5L9\u002f3Cop7I\u002fcU\u002fX0WW2sT8="}},"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H90pv0Z1AizP6jpHEGqBrM\u002fDtM1qlTqsT8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1 ...

# %% [markdown]
# ### Q: How did the ROAS change quarter after quarter starting 2024?
#
# Filter by date range and then view quarterly ROAS.

# %%
filtered_data_2024 = mmm.data.filter_dates(start_date="2024-01-01")
filtered_summary_2024 = MMMSummaryFactory(filtered_data_2024, mmm)
filtered_factory_2024 = MMMPlotlyFactory(summary=filtered_summary_2024)

filtered_factory_2024.roas(
    frequency="quarterly",
    color="channel",
    x="date",
    hdi_prob=None,
    title="ROAS from 2024 onwards (quarterly)",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b70957ab-8470-4e49-8a58-d62993de9936" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b70957ab-8470-4e49-8a58-d62993de9936")) {                    Plotly.newPlot(                        "b70957ab-8470-4e49-8a58-d62993de9936",                        [{"alignmentgroup":"True","customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2024-Q1","2024-Q2","2024-Q3","2024-Q4","2025-Q1","2025-Q2"],"xaxis":"x","y":{"dtype":"f8","bdata":"HfgtoASwsT+z7TL8njOwP9ZGStaEmrE\u002fG4NstCS2sD\u002fFyUOEwXSuP5mIWfLi57M\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_b"],["geo_b"],["geo_b"],["geo_b"],["geo_b"],["geo_b"]],"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":false,"textposition":"auto","x":["2024-Q1","2024-Q2","2024-Q3","2024-Q4","2025-Q1","2025-Q2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"3cXbxIZVsT9sY7sII\u002fKwPye7vXHf7LE\u002ftcqTIGoNsT+CIAh5siewPy\u002fcXYmcdbQ\u002f"},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2024-Q1","2024-Q2","2024-Q3","2024-Q4","2025-Q1","2025-Q2"],"xaxis":"x","y":{"dtype":"f8","bdata":"r8RpCJhHsT8SLecWYZmyPzm5GmoD27M\u002fAAAAAAAA+H8AAAAAAAD4fw7TNapU6rE\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_b"],["geo_b"],["geo_b"],["geo_b"],["geo_b"],["geo_b"]],"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":false,"textposition":"auto","x":["2024-Q1","2024-Q2","2024-Q3","2024-Q4","2025-Q1","2025-Q2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAA+H8N\u002fR\u002fUJ+yoPw4klifHp6k\u002fAf3gl34LsD8AAAAAAAD4f90QtuF1yaY\u002f"},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444," ...

# %% [markdown]
# ---
#
# ## Summary
#
# The `plot_interactive` module provides a rich set of interactive visualizations for
# exploring MMM results:
#
# | Method | What It Shows | Key Parameters |
# |--------|--------------|----------------|
# | `posterior_predictive()` | Actual vs predicted with HDI band | `hdi_prob`, `frequency` |
# | `contributions()` | Channel/control/seasonality contributions | `component`, `frequency`, `color`, `x` |
# | `roas()` | Return on Ad Spend | `frequency`, `color`, `x` |
# | `saturation_curves()` | Diminishing returns curves | `hdi_prob`, `max_value`, `original_scale` |
# | `adstock_curves()` | Carryover effect curves | `hdi_prob`, `amount` |
#
# **Key features:**
# - **Auto-faceting**: Custom dimensions (e.g., geo) automatically create subplots
# - **Facet control**: Use `facet_col`, `facet_row`, and `auto_facet` to customize layout
# - **Filtering**: Use `mmm.data.filter_dims()` or `filter_dates()` to focus on subsets
# - **Aggregating**: Use `mmm.data.aggregate_dims()` to combine dimensions
# - **Error bars**: Control with `hdi_prob` (set to `None` to remove)
# - **Customizable**: All Plotly Express kwargs (title, height, width, colors, etc.) are supported

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Tue, 10 Feb 2026
#
# Python implementation: CPython
# Python version       : 3.13.12
# IPython version      : 9.10.0
#
# numpy         : 2.3.5
# pandas        : 2.3.3
# plotly        : 6.5.2
# pymc_extras   : 0.8.0
# pymc_marketing: 0.18.0
#
# Watermark: 2.6.0
