# %% [markdown]
# # Interactive MMM Visualizations with `plot_interactive`
#
# This notebook demonstrates the **interactive plotting capabilities** of the
# `plot_interactive` module in `pymc-marketing`. These Plotly-based visualizations
# are designed for exploring MMM results interactively — hovering over data points,
# zooming into time ranges, and faceting across custom dimensions like markets.
#
# We use the **multidimensional MMM** example data (two geos: `geo_a` and `geo_b`,
# two channels: `x1` and `x2`) and fit the model using the same setup as the
# [MMM Multidimensional Example Notebook](https://www.pymc-marketing.io/en/stable/notebooks/mmm/mmm_multidimensional_example.html).
#
# **What this notebook covers:**
#
# - Posterior predictive checks (actual vs predicted)
# - ROAS analysis at different time granularities
# - Channel contributions over time
# - Saturation curves (diminishing returns)
# - Adstock curves (carryover effects)
# - Auto-faceting across custom dimensions
# - Advanced: Filtering and aggregating data with `MMMSummaryFactory` and `MMMPlotlyFactory`

# %%
import warnings

import numpy as np
import pandas as pd
import plotly.io as pio
from pymc_extras.prior import Prior

from pymc_marketing.mmm import GeometricAdstock, LogisticSaturation
from pymc_marketing.mmm.mmm import MMM
from pymc_marketing.paths import data_dir
from pymc_marketing.special_priors import LaplacePrior, LogNormalPrior

warnings.filterwarnings("ignore", category=UserWarning)

pio.renderers.default = "notebook_connected"

seed: int = sum(map(ord, "plot_interactive"))
rng: np.random.Generator = np.random.default_rng(seed=seed)

# %% [markdown]
# ## Load Data & Fit Model
#
# We load the same simulated multidimensional dataset used in the
# [MMM Multidimensional Example](https://www.pymc-marketing.io/en/stable/notebooks/mmm/mmm_multidimensional_example.html).
# The data has two geographies (`geo_a`, `geo_b`) and two channels (`x1`, `x2`).
#
# For model fitting details (prior specification, adstock/saturation choices,
# pooling strategies), please refer to the original notebook. Here we set up
# and fit the model quickly so we can focus on **interactive visualizations**.

# %%
data_path = data_dir / "mmm_multidimensional_example.csv"
data_df = pd.read_csv(data_path, parse_dates=["date"])
data_df.head()
# Out:
#         date    geo           x1           x2  event_1  event_2            y
# 0 2022-06-06  geo_a  5527.640078     0.000000        0        0  2647.596355
# 1 2022-06-06  geo_b  8849.257500  8063.918386        0        0   682.406280
# 2 2022-06-13  geo_a  6692.655692     0.000000        0        0  5020.823907
# 3 2022-06-13  geo_b  9073.817994  9354.014585        0        0  3753.104897
# 4 2022-06-20  geo_a  7124.016733     0.000000        0        0  6184.322132

# %%
# --- Prior Specification ---
# Hierarchical beta (partially pooled across geos)
beta_prior = LogNormalPrior(
    mean=Prior("Gamma", mu=0.25, sigma=0.10, dims=("channel")),
    std=Prior("Exponential", scale=0.10, dims=("channel")),
    dims=("channel", "geo"),
    centered=False,
)

# Saturation: beta is hierarchical, lambda is fully pooled
saturation = LogisticSaturation(
    priors={
        "beta": beta_prior,
        "lam": Prior("Gamma", mu=0.5, sigma=0.25, dims=("channel")),
    }
)

# Adstock: unpooled (each geo x channel has its own alpha)
adstock = GeometricAdstock(
    priors={"alpha": Prior("Beta", alpha=2, beta=5, dims=("geo", "channel"))},
    l_max=8,
)

# Model config
model_config = {
    "intercept": Prior("Gamma", mu=0.5, sigma=0.25, dims="geo"),
    "gamma_control": Prior("Normal", mu=0, sigma=0.5, dims="control"),
    "gamma_fourier": LaplacePrior(
        mu=0,
        b=Prior("HalfNormal", sigma=0.2),
        dims=("geo", "fourier_mode"),
        centered=False,
    ),
    "likelihood": Prior(
        "TruncatedNormal",
        lower=0,
        sigma=Prior("HalfNormal", sigma=1.5),
        dims=("date", "geo"),
    ),
}

# --- Model Definition ---
mmm = MMM(
    date_column="date",
    target_column="y",
    channel_columns=["x1", "x2"],
    control_columns=["event_1", "event_2"],
    dims=("geo",),
    scaling={
        "channel": {"method": "max", "dims": ()},
        "target": {"method": "max", "dims": ()},
    },
    adstock=adstock,
    saturation=saturation,
    yearly_seasonality=2,
    model_config=model_config,
)

# --- Fit ---
x_train = data_df.drop(columns=["y"])
y_train = data_df["y"]

mmm.fit(
    X=x_train,
    y=y_train,
    chains=4,
    target_accept=0.95,
    random_seed=rng,
)

# --- Add original scale deterministic variables ---
mmm.build_model(X=x_train, y=y_train)
mmm.add_original_scale_contribution_variable(
    var=[
        "channel_contribution",
        "control_contribution",
        "intercept_contribution",
        "yearly_seasonality_contribution",
        "y",
    ]
)

# --- Posterior predictive ---
mmm.sample_posterior_predictive(X=x_train, random_seed=rng)
# Out:
# NUTS[nutpie]: [adstock_alpha, saturation_lam, saturation_beta_mean, saturation_beta_std, saturation_beta_log_offset, gamma_fourier_b, gamma_fourier_sigma, gamma_fourier_offset, gamma_control, y_sigma, intercept_contribution]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling: [y]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <xarray.Dataset> Size: 20MB
# Dimensions:           (date: 159, geo: 2, sample: 4000)
# Coordinates:
#   * date              (date) datetime64[ns] 1kB 2022-06-06 ... 2025-06-16
#   * geo               (geo) <U5 40B 'geo_a' 'geo_b'
#   * sample            (sample) object 32kB MultiIndex
#   * chain             (sample) int64 32kB 0 0 0 0 0 0 0 0 0 ... 3 3 3 3 3 3 3 3
#   * draw              (sample) int64 32kB 0 1 2 3 4 5 ... 995 996 997 998 999
# Data variables:
#     y                 (date, geo, sample) float64 10MB 0.2783 0.139 ... 0.2213
#     y_original_scale  (date, geo, sample) float64 10MB 3.844e+03 ... 2.435e+03
# Attributes:
#     created_at:                 2026-06-30T16:55:11.323077+00:00
#     creation_library:           ArviZ
#     creation_library_version:   1.2.0
#     creation_library_language:  Python
#     inference_library:          pymc
#     inference_library_version:  6.0.1
#     sample_dims:                ['sample']

# %% [markdown]
# ---
#
# ## 1. Posterior Predictive: How Well Does the Model Fit?
#
# The posterior predictive plot shows the model's predictions (with uncertainty)
# against the observed data. This is the first thing to check after fitting —
# do the predictions track the actual sales?
#
# The interactive plot lets you **hover** over any point to see exact values,
# and **zoom** into specific time periods.

# %%
mmm.plot_interactive.posterior_predictive()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8b0a7c5f-5678-4588-b4ad-0905473a1b53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8b0a7c5f-5678-4588-b4ad-0905473a1b53")) {                    Plotly.newPlot(                        "8b0a7c5f-5678-4588-b4ad-0905473a1b53",                        [{"customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"=Predicted\u003cbr\u003eDate=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Predicted","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Predicted","orientation":"v","showlegend":true,"x":["2022-06-06T00:00:00.000000000","2022-06-13T00:00:00.000000000","2022-06-20T00:00:00.000000000","2022-06-27T00:00:00.000000000","2022-07-04T00:00:00.000000000","2022-07-11T00:00:00.000000000","2022-07-18T00:00:00.000000000","2022-07-25T00:00:00.000000000","2022-08-01T00:00:00.000000000","2022-08-08T00:00:00.000000000","2022-08-15T00:00:00.000000000","2022-08-22T00:00:00.000000000","2022-08-29T00:00:00.000000000","2022-09-05T00:00:00.000000000","2022-09-12T00:00:00.000000000","2022-09-19T00:00:00.000000000","2022-09-26T00:00:00.000000000","2022-10-03T00:00:00.000000000","2022-10-10T00:00:00.000000000","2022-10-17T00:00:00.000000000","2022-10-24T00:00:00.000000000","2022-10-31T00:00:00.000000000","2022-11-07T00:00:00.000000000","2022-11-14T00:00:00.000000000","2022-11-21T00:00:00.000000000","2022-11-28T00:00:00.000000000","2022-12-05T00:00:00.000000000","2022-12-12T00:00:00.000000000","2022-12-19T00:00:00.000000000","2022-12-26T00:00:00.000000000","2023-01-02T00:00:00.000000000","2023-01-09T00:00:00.000000000","2023-01-16T00:00:00.000000000","2023-01-23T00:00:00.000000000","2023-01-30T00:00:00.000000000","2023-02-06T00:00:00.000000000","2023-02-13T00:00:00.000000000","2023-02-20T00:00:00.000000000","2023-02-27T00:00:00.000000000","2023-03-06T00:00:00.000000000","2023-03-13T00:00:00.000000000","2023-03-20T00:00:00.000000000","2023-03-27T00:00:00.000000000","2023-04-03T00:00:00.000000000","2023-04-10T00:00:00.000000000","2023-04-17T00:00:00.000000000","2023-04-24T00:00:00.000000000 ...

# %% [markdown]
# ---
#
# ## 2. ROAS Analysis: Which Channels Give the Best Return?
#
# ROAS (Return on Ad Spend) is one of the most important metrics for marketers.
# The `plot_interactive` module makes it easy to slice and dice ROAS across
# different time granularities and dimensions.
#
# ### Q: How did the ROAS of each channel change year after year?

# %%
mmm.plot_interactive.roas(
    frequency="yearly",
    color="date",
    x="channel",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="d7610fa7-9263-47e2-a8c4-6f5ccc39f5bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d7610fa7-9263-47e2-a8c4-6f5ccc39f5bf")) {                    Plotly.newPlot(                        "d7610fa7-9263-47e2-a8c4-6f5ccc39f5bf",                        [{"alignmentgroup":"True","customdata":[["0.064 HDI: [0.0, 0.133]","geo_a"],["nan HDI: [nan, nan]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"jBo1okTSsT\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002ffw=="},"arrayminus":{"dtype":"f8","bdata":"NTqhp8hIsD8AAAAAAAD4fw=="}},"hovertemplate":"date=2022\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2022","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2022","offsetgroup":"2022","orientation":"v","showlegend":true,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"zEKcsP5ZsD8AAAAAAAD4fw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.067 HDI: [0.001, 0.147]","geo_b"],["0.05 HDI: [0.002, 0.107]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"jV14eTmRtD\u002fs8Kiwo8asPw=="},"arrayminus":{"dtype":"f8","bdata":"0GDtAjW+sD9GAI867dKoPw=="}},"hovertemplate":"date=2022\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2022","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2022","offsetgroup":"2022","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"l1UswDUgsT\u002fs\u002fvapedOpPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["0.064 HDI: [0.0, 0.134]","geo_a"],["0.074 HDI: [0.002, 0.156]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"XSTp\u002fEPpsT\u002fg\u002fxB5V\u002fq0Pw=="},"arrayminus":{"dtype":"f8","bdata":"HDa0fvBasD9itFPSeZuyPw=="}},"hovertemplate":"date=2023\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2023","offsetgroup":"2023","orientation":"v","showlegend":true,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"3VtpVD92sD+yYq0o+A2zPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.066 HDI: [0.002, 0.146]","geo_b"],["0.051 HDI: [0.003, 0.108]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"\u002fg3rsmxztD\u002fAhsm662+tPw=="},"arrayminus":{"dtype":"f8","bdata":"\u002fJ4WQ\u002fyesD+DDZtKhHuoPw=="}},"hovertemplate":"date=2023\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2023","offsetgroup":"2023","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"Ri6NovcFsT82+BYnseepPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["0.067 HDI: [0.0, 0.139]","geo_a"],["0.074 HDI: [0.002, 0.156]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"b3hJ0TqZsj8JYF3aLPu0Pw=="},"arrayminus":{"dtype":"f8","bdata":"YNzu7Uv3sD+W8+z4RpmyPw=="}},"hovertemplate":"date=2024\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2024","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"2024","offsetgroup":"2024","orientation":"v","showlegend":true,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"y18lwLAJsT8TD4EsxAuzPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.068 HDI: [0.002, 0.15]","geo_b"],["0.051 HDI: [0.003, 0.108]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"SBKyLQ3ptD9 ...

# %% [markdown]
# ### Q: Within each year, which channel performed better in each geo?
#
# By swapping `x` and `color`, we get a different perspective — now the x-axis
# shows time and the color differentiates channels.

# %%
mmm.plot_interactive.roas(
    frequency="yearly",
    color="channel",
    x="date",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="d7f8070e-5758-4f09-baa7-51884c1d7b93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d7f8070e-5758-4f09-baa7-51884c1d7b93")) {                    Plotly.newPlot(                        "d7f8070e-5758-4f09-baa7-51884c1d7b93",                        [{"alignmentgroup":"True","customdata":[["0.064 HDI: [0.0, 0.133]","geo_a"],["0.064 HDI: [0.0, 0.134]","geo_a"],["0.067 HDI: [0.0, 0.139]","geo_a"],["0.065 HDI: [0.0, 0.136]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"jBo1okTSsT9dJOn8Q+mxP294SdE6mbI\u002fWDcq5Qgisj8="},"arrayminus":{"dtype":"f8","bdata":"NTqhp8hIsD8cNrR+8FqwP2Dc7u1L97A\u002fWKFhSBGFsD8="}},"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"zEKcsP5ZsD\u002fdW2lUP3awP8tfJcCwCbE\u002fyIUcvcaWsD8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.067 HDI: [0.001, 0.147]","geo_b"],["0.066 HDI: [0.002, 0.146]","geo_b"],["0.068 HDI: [0.002, 0.15]","geo_b"],["0.067 HDI: [0.002, 0.148]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"jV14eTmRtD\u002f+DeuybHO0P0gSsi0N6bQ\u002fmOc6wKO8tD8="},"arrayminus":{"dtype":"f8","bdata":"0GDtAjW+sD\u002f8nhZD\u002fJ6wP37vf8YtCbE\u002fNSkmrPnbsD8="}},"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"l1UswDUgsT9GLo2i9wWxPxauafmZbLE\u002frlzgRWM+sT8="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["nan HDI: [nan, nan]","geo_a"],["0.074 HDI: [0.002, 0.156]","geo_a"],["0.074 HDI: [0.002, 0.156]","geo_a"],["0.07 HDI: [0.002, 0.147]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f3\u002fg\u002fxB5V\u002fq0PwlgXdos+7Q\u002f\u002fwNLEPuhsz8="},"arrayminus":{"dtype":"f8","bdata":"AAAAAAAA+H9itFPSeZuyP5bz7PhGmbI\u002fWle2\u002fbtVsT8="}},"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H+yYq0o+A2zPxMPgSzEC7M\u002fzcVdM8zqsT8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.05 HDI: [0.002, 0.107]","geo_b"],["0.051 HDI: [0.003, 0.108]","geo_b"],["0.051 HDI: [0.003, 0.108]","geo_b"],["0.045 HDI: [0.002, 0.097]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"7PCosKPGrD\u002fAhsm662+tP3c3vlY8Vq0\u002fadmDsud4qj8="},"arrayminus":{"dtype":"f8","bdata":"RgCPOu3SqD+DDZtKhHuoP3kkkG3me6g\u002f1vEjsjYGpj8="}},"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"7P72qXnTqT82+BYnseepP\u002fU2haXI3qk\u002fPS9YxXD1pj8="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorsca ...

# %% [markdown]
# ### Q: Looking over all the data, which channel performed better in each geo?
#
# Using `frequency="all_time"` aggregates everything into a single time period,
# giving us the overall ROAS per channel per geo.

# %%
mmm.plot_interactive.roas(frequency="all_time")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="50eb74ae-7ad2-44a0-bd10-5ec4b27f446d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("50eb74ae-7ad2-44a0-bd10-5ec4b27f446d")) {                    Plotly.newPlot(                        "50eb74ae-7ad2-44a0-bd10-5ec4b27f446d",                        [{"alignmentgroup":"True","customdata":[["0.065 HDI: [0.0, 0.136]","geo_a"],["0.074 HDI: [0.002, 0.155]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"\u002f70iTd4nsj9oVnb3HdO0Pw=="},"arrayminus":{"dtype":"f8","bdata":"P5lnMreBsD98H+cZ33SyPw=="}},"hovertemplate":"ROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"iYdIanidsD\u002fmiapq2ueyPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.067 HDI: [0.002, 0.148]","geo_b"],["0.05 HDI: [0.003, 0.107]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"6s495uKjtD\u002fe6VFx2hWtPw=="},"arrayminus":{"dtype":"f8","bdata":"3\u002fhHafbOsD8frdjJSU2oPw=="}},"hovertemplate":"ROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"vCqctVQxsT9KW23hfa2pPw=="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","s ...

# %% [markdown]
# ---
#
# ## 3. Channel Contributions: What Drives Sales?
#
# The contributions plot shows how much each channel contributes to total sales
# over time. It supports the same `frequency`, `color`, and `x` parameters as
# `roas()` above, so you can slice contributions in exactly the same way —
# by time granularity, channel, or geography.
#
# ### Q: What is the overall contribution of each channel across all geos?
#
# Error bars show the 94% HDI (Highest Density Interval).

# %%
mmm.plot_interactive.contributions(frequency="all_time")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="c088e9df-1dd2-4d23-a07f-7f0ff3872a67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c088e9df-1dd2-4d23-a07f-7f0ff3872a67")) {                    Plotly.newPlot(                        "c088e9df-1dd2-4d23-a07f-7f0ff3872a67",                        [{"alignmentgroup":"True","customdata":[["38451 HDI: [251, 80467]","geo_a"],["32290 HDI: [767, 67857]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"BD232wOE5EA7WU5+4V3hQA=="},"arrayminus":{"dtype":"f8","bdata":"KiwXSP2m4kC9rLMLm8jeQA=="}},"hovertemplate":"Contribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x","y":{"dtype":"f8","bdata":"lvvRD1rG4kBGAmApYojfQA=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["50654 HDI: [1132, 111466]","geo_b"],["23630 HDI: [1266, 50396]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"98eDRHWx7UDet92ncSPaQA=="},"arrayminus":{"dtype":"f8","bdata":"F4ggRkou6ECXAy9789bVQA=="}},"hovertemplate":"Contribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["x1","x2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"I1Bsz8276EBw2s0zeBPXQA=="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":1 ...

# %% [markdown]
# ### Q: How did channel contributions change year by year?
#
# Just like the ROAS examples, setting `frequency="yearly"`, `color="channel"`,
# and `x="date"` gives us a time-series view colored by channel.

# %%
mmm.plot_interactive.contributions(
    frequency="yearly",
    color="channel",
    x="date",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="cef037d3-bf22-4470-bd26-561a71191a26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cef037d3-bf22-4470-bd26-561a71191a26")) {                    Plotly.newPlot(                        "cef037d3-bf22-4470-bd26-561a71191a26",                        [{"alignmentgroup":"True","customdata":[["8489 HDI: [35, 17742]","geo_a"],["14736 HDI: [95, 30770]","geo_a"],["11293 HDI: [48, 23620]","geo_a"],["3932 HDI: [16, 8230]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"+VOUYjgSwkBUcGlJ7FDPQJm6G067E8hAtgyGZffJsEA="},"arrayminus":{"dtype":"f8","bdata":"bKwjYjiDwEBcuNJVfJjMQADyW2qw9sVAwRguejeXrkA="}},"hovertemplate":"channel=x1\u003cbr\u003eContribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"ETg6LqyUwECyzMstO8jMQO3490yADsZAeMMnWQK4rkA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["11499 HDI: [257, 25309]","geo_b"],["18603 HDI: [440, 40952]","geo_b"],["16382 HDI: [365, 36042]","geo_b"],["4170 HDI: [93, 9185]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"34qZhNX4ykCPfJ8pNtPVQPtmpp73MtNA4nabiN2Ws0A="},"arrayminus":{"dtype":"f8","bdata":"yZXvdvL0xUAKCqik5LzRQKXo3Q6JSM9AzqVplUTar0A="}},"hovertemplate":"channel=x1\u003cbr\u003eContribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"+Y8P7Xd1xkAF5zl3yyrSQGrpyocb\u002f89AFvLFtBlKsEA="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["0 HDI: [0, 0]","geo_a"],["14058 HDI: [330, 29536]","geo_a"],["14327 HDI: [336, 30110]","geo_a"],["3904 HDI: [127, 8182]","geo_a"]],"error_y":{"array":{"dtype":"f8","bdata":"AAAAAAAAAADE1ATtpDrOQOaGLhKM085AsbRDJ7a1sEA="},"arrayminus":{"dtype":"f8","bdata":"AAAAAAAAAADXRi4TJ9DKQMI7DOF1U8tARe7EOhaCrUA="}},"hovertemplate":"channel=x2\u003cbr\u003eContribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAB0dAgsI3XLQJxxtiOs+8tACnkEDNR\u002frkA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2096 HDI: [81, 4432]","geo_b"],["9685 HDI: [532, 20690]","geo_b"],["10377 HDI: [556, 22145]","geo_b"],["1472 HDI: [60, 3168]","geo_b"]],"error_y":{"array":{"dtype":"f8","bdata":"R3igvLg\u002fokBFNh4qhn7FQPijT9j0+8ZAWOD7\u002fwqDmkA="},"arrayminus":{"dtype":"f8","bdata":"2WMT9z18n0Dvwu63XuDBQKK6JmijLsNAQNkI7KUOlkA="}},"hovertemplate":"channel=x2\u003cbr\u003eContribution=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"P+daL9FgoECL36TkR+rCQD57isOsRMRA2gGtnDv+lkA="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555 ...

# %% [markdown]
# ### Q: How did the contributions of control variables change year by year?
#
# On top of channel contributions, we can also plot the contributions of control, seasonality, and baseline variables.

# %%
mmm.plot_interactive.contributions(
    component="control",
    frequency="yearly",
    color="control",
    x="date",
    hdi_prob=None,
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="18a425dd-5e7a-4b77-bc0d-b566eb7d8f6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("18a425dd-5e7a-4b77-bc0d-b566eb7d8f6e")) {                    Plotly.newPlot(                        "18a425dd-5e7a-4b77-bc0d-b566eb7d8f6e",                        [{"alignmentgroup":"True","customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"control=event_1\u003cbr\u003eContribution=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"event_1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"event_1","offsetgroup":"event_1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"v56JXcpfsEC\u002fnoldyl\u002fAQAAAAAAAAAAAAAAAAAAAAAA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_b"],["geo_b"],["geo_b"],["geo_b"]],"hovertemplate":"control=event_1\u003cbr\u003eContribution=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"event_1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"event_1","offsetgroup":"event_1","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"PqUDNIcWqkA+pQM0hxa6QAAAAAAAAAAAAAAAAAAAAAA="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"control=event_2\u003cbr\u003eContribution=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"event_2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"event_2","offsetgroup":"event_2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAADUAX0mZYilwNQBfSZliJXAAAAAAAAAAAA="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_b"],["geo_b"],["geo_b"],["geo_b"]],"hovertemplate":"control=event_2\u003cbr\u003eContribution=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"event_2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"event_2","offsetgroup":"event_2","orientation":"v","showlegend":false,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAAAA7jyW7SCehwDuPJbtIJ5HAAAAAAAAAAAA="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type ...

# %% [markdown]
# ---
#
# ## 4. Saturation Curves: Where Are Diminishing Returns?
#
# Saturation curves show how the response (contribution) changes as spend
# increases. These are essential for understanding where additional spend
# will have diminishing returns.
#
# ### Q: Show me the saturation curves in original scale
#
# By default, the x-axis is in original scale (e.g., dollars of spend).
# Each channel gets its own line, faceted by geo.

# %%
mmm.plot_interactive.saturation_curves()
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="45a0a919-8033-4e3d-b484-82af0f1260ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("45a0a919-8033-4e3d-b484-82af0f1260ad")) {                    Plotly.newPlot(                        "45a0a919-8033-4e3d-b484-82af0f1260ad",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAB+MqffY4hXQH4yp99jiGdA3mW950qmcUB+MqffY4h3QB7\u002fkNd8an1A3mW950qmgUAvTLJjV5eEQH4yp99jiIdAzRicW3B5ikAe\u002f5DXfGqNQLfywqnELZBA3mW950qmkUAG2bcl0R6TQC9MsmNXl5RAVr+sod0PlkB+MqffY4iXQKaloR3qAJlAzRicW3B5mkD2i5aZ9vGbQB7\u002fkNd8ap1ARXKLFQPjnkC38sKpxC2gQEsswMgH6qBA3mW950qmoUByn7oGjmKiQAbZtyXRHqNAmxK1RBTbo0AvTLJjV5ekQMKFr4KaU6VAVr+sod0PpkDq+KnAIMymQH4yp99jiKdAEmyk\u002fqZEqECmpaEd6gCpQDrfnjwtvalAzRicW3B5qkBhUpl6szWrQPaLlpn28atAisWTuDmurEAe\u002f5DXfGqtQLI4jva\u002fJq5ARXKLFQPjrkDZq4g0Rp+vQLfywqnELbBAgY9BOeaLsEBLLMDIB+qwQBXJPlgpSLFA3mW950qmsUCoAjx3bASyQHKfugaOYrJAPTw5lq\u002fAskAG2bcl0R6zQNB1NrXyfLNAmxK1RBTbs0BkrzPUNTm0QC9MsmNXl7RA+Ogw83j1tEDCha+CmlO1QIwiLhK8sbVAVr+sod0PtkAgXCsx\u002f222QOr4qcAgzLZAtJUoUEIqt0B+MqffY4i3QEfPJW+F5rdAEmyk\u002fqZEuEDcCCOOyKK4QKaloR3qALlAcEIgrQtfuUA63548Lb25QAR8HcxOG7pAzRicW3B5ukCYtRrrkde6QGFSmXqzNbtALO8XCtWTu0D2i5aZ9vG7QL8oFSkYULxAisWTuDmuvEBTYhJIWwy9QB7\u002fkNd8ar1A55sPZ57IvUCyOI72vya+QHvVDIbhhL5ARXKLFQPjvkAPDwqlJEG\u002fQNmriDRGn79ApEgHxGf9v0C38sKpxC3AQBxBgnHVXMBAgY9BOeaLwEDl3QAB97rAQEsswMgH6sBAr3p\u002fkBgZwUAVyT5YKUjBQHkX\u002fh86d8FA3mW950qmwUBEtHyvW9XBQKgCPHdsBMJADVH7Pn0zwkA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACMVscvDmIZQPydDpf\u002fYSlAWxGecm0JM0Csv4c1xWE5QITqQ8n\\u002fLJeScEAMjjHWivZwQL3p\u002fZdrWnFA9lx9CTm+cUAwjhXD8iFyQLucu12YhXJAXH32cinpckBcSuGcpUxzQIuHLXYMsHNAkVklml0TdEC2sK2kmHZ0QPFmSDK92XRAeVEW4Mo8dUAXRdlLwZ91QGEO9hOgAnZACFx212ZldkBNnQo2Fch2QK\u002fSC9CqKndAD1J9RieNd0CofQ47iu93QPVtHFDTUXhA8Y6zKAK0eEDNL5FoFhZ5QBsGJbQPeHlAxKOSsO3ZeUAl4LIDsDt6QFA0FVRWnXpAHQoBSeD+ekAA\u002f3aKTWB7QIQZMsGdwXtAU\u002fKoltAifEC20A615YN8QEG6VMfc5HxAJXYqebVFfUADhP92b6Z9QMUGBG4KB35AVqIpDIZnfkBtTiQA4sd+QEIca\u002fkdKH9AtfA4qDmIf0AwM429NOh\u002fQMU3lnUHJIBA3XbQ8eNTgECAnh2tr4OAQCpaiYFqs4BAuvOCSRTjgEBCiN3frBKBQL830B80QoFACk\u002f25KlxgUCZbE8LDqGBQAWgP29g0IFAWoSP7aD\u002fgUA+VWxjzy6CQC\u002f\u002fZ67rXYJAfSp5rPWMgkDbQfs77buCQKNzrjvS6oJAwa63iqQZg0A="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002f6ukTjpq9ARWxtkg8+sEBbW32CraiwQHBKjXJLE7FAhTmdYul9sUCbKK1Sh+ixQLAXvUIlU7JAxgbNMsO9skDb9dwiYSizQPHk7BL\u002fkrNABtT8Ap39s0AcwwzzOmi0QDGyHOPY0rRAR6Es03Y9tUBckDzDFKi1QHF\u002fTLOyErZAh25co1B9tkCcXWyT7ue2QLJMfIOMUrdAxzuMcyq9t0DcKpxjyCe4QPMZrFNmkrhABwm8QwT9uEAe+Mszome5QDPn2yNA0rlASdbrE948ukBexfsDfKe6QHO0C\u002fQZErtAiaMb5Ld8u0CekivUVee7QLSBO8TzUbxAyXBLtJG8vEDfX1ukLye9QPROa5TNkb1ACT57hGv8vUAfLYt0CWe+Q ...

# %% [markdown]
# ### Q: Now show me with uncertainty (HDI bands)
#
# Adding `hdi_prob=0.9` draws shaded bands showing the 90% HDI around
# each curve — capturing posterior uncertainty in the saturation parameters.

# %%
mmm.plot_interactive.saturation_curves(hdi_prob=0.9)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="bf67ebc9-d951-4d32-ae56-fa8996f558fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bf67ebc9-d951-4d32-ae56-fa8996f558fb")) {                    Plotly.newPlot(                        "bf67ebc9-d951-4d32-ae56-fa8996f558fb",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAB+MqffY4hXQH4yp99jiGdA3mW950qmcUB+MqffY4h3QB7\u002fkNd8an1A3mW950qmgUAvTLJjV5eEQH4yp99jiIdAzRicW3B5ikAe\u002f5DXfGqNQLfywqnELZBA3mW950qmkUAG2bcl0R6TQC9MsmNXl5RAVr+sod0PlkB+MqffY4iXQKaloR3qAJlAzRicW3B5mkD2i5aZ9vGbQB7\u002fkNd8ap1ARXKLFQPjnkC38sKpxC2gQEsswMgH6qBA3mW950qmoUByn7oGjmKiQAbZtyXRHqNAmxK1RBTbo0AvTLJjV5ekQMKFr4KaU6VAVr+sod0PpkDq+KnAIMymQH4yp99jiKdAEmyk\u002fqZEqECmpaEd6gCpQDrfnjwtvalAzRicW3B5qkBhUpl6szWrQPaLlpn28atAisWTuDmurEAe\u002f5DXfGqtQLI4jva\u002fJq5ARXKLFQPjrkDZq4g0Rp+vQLfywqnELbBAgY9BOeaLsEBLLMDIB+qwQBXJPlgpSLFA3mW950qmsUCoAjx3bASyQHKfugaOYrJAPTw5lq\u002fAskAG2bcl0R6zQNB1NrXyfLNAmxK1RBTbs0BkrzPUNTm0QC9MsmNXl7RA+Ogw83j1tEDCha+CmlO1QIwiLhK8sbVAVr+sod0PtkAgXCsx\u002f222QOr4qcAgzLZAtJUoUEIqt0B+MqffY4i3QEfPJW+F5rdAEmyk\u002fqZEuEDcCCOOyKK4QKaloR3qALlAcEIgrQtfuUA63548Lb25QAR8HcxOG7pAzRicW3B5ukCYtRrrkde6QGFSmXqzNbtALO8XCtWTu0D2i5aZ9vG7QL8oFSkYULxAisWTuDmuvEBTYhJIWwy9QB7\u002fkNd8ar1A55sPZ57IvUCyOI72vya+QHvVDIbhhL5ARXKLFQPjvkAPDwqlJEG\u002fQNmriDRGn79ApEgHxGf9v0C38sKpxC3AQBxBgnHVXMBAgY9BOeaLwEDl3QAB97rAQEsswMgH6sBAr3p\u002fkBgZwUAVyT5YKUjBQHkX\u002fh86d8FA3mW950qmwUBEtHyvW9XBQKgCPHdsBMJADVH7Pn0zwkA="},"xaxis":"x","y":{"dtype":"f8","bdata":"...\u002fdwQG4\u002fH57vWnFAS2XFq8i+cUDzP6+TjiJyQHVFzvFAhnJAE4+hYt\u002fpckDoFziDaU1zQFfwMvHesHNAfmTHSj8UdEAtF8Euind0QCIQhDy\u002f2nRA3L0OFN49dUBT6\u002ftV5qB1QP2ohKPXA3ZAPymCnrFmdkBUkG\u002fpc8l2QPK3ayceLHdAp+U6\u002fK+Od0AQdUgMKfF3QHV1qPyIU3hASToZc8+1eECH3wQW\u002fBd5QDbBgowOenlAOuZYfgbceUCXXv2T4z16QFGVl3aln3pAtpUB0EsBe0D4Q8lK1mJ7QJeJMZJExHtAgXUzUpYlfECET383y4Z8QMyffe\u002fi53xAXCpQKN1IfUDp3dKQual9QEy3nNh3Cn5Au5gAsBdrfkAIFQ7ImMt+QG0vktL6K39A7w8Ygj2Mf0B1q+mJYOx\u002fQKIwCM8xJoBATcaqOSNWgEDOhaFfBIaAQG7dERzVtYBA\u002ffKBSpXlgEC81tjGRBWBQBqxXm3jRIFA3Oq8GnF0gUBkUP6r7aOBQIkvj\u002f5Y04FArXA98LICgkCBqjhf+zGCQEUxEioyYYJAniC9L1eQgkBvYY5Par+CQAqqPGlr7oJAy3rgXFodg0A="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002f6ukTjpq9ARWxtkg8+sEBbW32CraiwQHBKjXJLE7FAhTmdYul9sUCbKK1Sh+ixQLAXvUIlU7JAxgbNMsO9skDb9dwiYSizQPHk7BL\u002fkrNABtT8Ap39s0AcwwzzOmi0QDGyHOPY0rRAR6Es03Y9tUBckDzDFKi1QHF\u002fTLOyErZAh25co1B9tkCcXWyT7ue2QLJMfIOMUrdAxzuMcyq9t0DcKpxjyCe4QPMZrFNmkrhABwm8QwT9uEAe+Mszome5QDPn2yNA0rlASdbrE948ukBexfsDfKe6QHO0C\u002fQZErtAiaMb5Ld8u0CekivUVee7QLSBO8TzUbxAyXBLtJG8vEDfX1ukLye9QPROa5TNkb1ACT57hGv8vUAfLYt0CWe+QDQcm2Sn0b5ASgurVEU8v0Bf+rpE46a\u002fQLp0ZZrACMBARWxtkg8+wEDQY3WKXnPAQFtbfYKtqMBA5VKFevzdwEBwSo1ySxPBQPtBlWqaSMFAhTmdYul9wUAQMaVaOLPBQJsorVKH6MFAJiC1StYdwkCwF71CJVPCQDsPxTp0iMJAxgbNMsO9wkBQ\u002ftQqEvPCQNv13CJhKMNAZu3kGrBdw0Dx5OwS\u002f5LDQHzc9ApOyMNABtT8Ap39w0CRywT76zLEQBzDDPM6aMRAproU64mdxEA="},"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAAAD8f4zm9pAcQO4KncTlkCxAXglT6ZZsNUBLpJI+oZA8QIF1ZKlE2kFALrrpSyNsRUB1EH1A6P1IQBiem0GPj0xAN9xfBYoQUED1YUIsOdlRQK96ZfTSoVNAvX ...

# %% [markdown]
# ---
#
# ## 5. Adstock Curves: How Long Do Effects Last?
#
# Adstock (carryover) curves show how the effect of a marketing impulse
# decays over time. A slow decay means the channel has long-lasting effects;
# a fast decay means the effect is short-lived.
#
# ### Q: How do the decay curves look?

# %%
mmm.plot_interactive.adstock_curves(hdi_prob=None)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="e49dc184-3427-4c50-bda3-d37df74072b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e49dc184-3427-4c50-bda3-d37df74072b8")) {                    Plotly.newPlot(                        "e49dc184-3427-4c50-bda3-d37df74072b8",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"e\u002fzaiTUu5j8zq8L8vgTIP8HxNHbT1bA\u002fIbnUwzgXnD+udyLKOaWKP7IeZ7cC6Hs\u002f73bhFIuhbz8sINtiCiBjPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"zRKvBOkF6D8v2ZfpQDjFP71fXArcqqk\u002frzX1tfb0kj89Tj8sBDWAP6nwgur5Gm8\u002fJypsDnVnYD\u002fp1jXXlbVSPw=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"Q\u002fhCq4La5T\u002fFBeRXOfXHPySG8xeilrE\u002fg\u002f2qKIr9nj+ufa5WZeKOP4fZm1IBzIA\u002fjPB0qGR8cz+TZiqKBrxnPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"3jsixZU15z9lNqizinXGPyDB3jlCZa0\u002faViuSUE2lz+mE+MpxMeEPyz5V5DgWXQ\u002f8rSOIqxYZT8NeRk7xKtXPw=="},"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]} ...

# %% [markdown]
# ### Q: Show me adstock curves with uncertainty
#
# Adding HDI bands helps us understand how confident we are about the
# carryover duration for each channel.

# %%
mmm.plot_interactive.adstock_curves(hdi_prob=0.9)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="d852391f-d145-4a3f-a68c-6a4ef2dcf7e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d852391f-d145-4a3f-a68c-6a4ef2dcf7e5")) {                    Plotly.newPlot(                        "d852391f-d145-4a3f-a68c-6a4ef2dcf7e5",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"vpVLJPma5j+d\u002fV6ctnfHP1PKXrJH8a8\u002fGby6No\u002fmmT+q27Nwk9KHP0sH6aOkF3g\u002fYienOiw4aj\u002faXz\u002f3+DxePw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"O2Qc4ChT5z\u002f\u002fZPgOoXzGP+zfnRyVzKw\u002fX6TVftohlj+dB\u002fndPlWDPy7VPuMNi3I\u002fn+IvrM8SYz8NgMv0nrFUPw=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"SL5c3+ch5j+mCICZafHHP\u002fmSgkdEA7E\u002ffULmku3HnD8ofj+TyHyLP94\u002fQDFhwnw\u002f+hq3GzorcD\u002fzbc7Ua0djPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"gxuOEHVj5z9OTZU7w1rGP4DzOwXthKw\u002fQVbm4sXelT+zFBo0LxSDP0aRKm5HV3I\u002f+jhan+gLYz90HQ+r2RNVPw=="},"yaxis":"y2","type":"scatter"},{"fill":"toself","fillcolor":"rgba(99.0,110.0,250.0,0.2)","hoverinfo":"none","line":{"color":"rgba(255,255,255,0)"},"mode":"lines","name":"x1 HDI","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgcHBgUEAwIBAA=="},"y":{"dtype":"f8","bdata":"z8yGHTT\u002f3T+q0v4O90i3P9ToCN6oLzQ\u002f1BafBv3WyD4pKkZWhvBmPnFfX5JGLwU+vjBB62SQoz2XgFNSQBFCPcUIlmByUXM\u002f\u002fIhe77+7gj\u002fNSR2AlSqSP0GJ4fXPnaE\u002fkyPSQ00VsT9u18Bte5LAP1OzFbAzEdA\u002fWFbOACbX7j8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","fillcolor":"rgba(239.0,85.0,59.0,0.2)","hoverinfo":"none","line":{"color":"rgba(255,255,255,0)"},"mode":"lines","name":"x2 HDI","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgcHBgUEAwIBAA=="},"y":{"dtype":"f8","bdata":"38wGQomf3D9Qzy1mATS3P7oNLoe5SFU\u002fZSlS6LUABz+fZoSiOke6PgldMdAlBW4+VmD09rslIT5sQoyezpbTPZnKFrdZ33s\u002fRp52e4dniT\u002fMNECPpyeXP5YsF7zFGqU\u002fYH7VF148sz985CPP2InBP3HVlGA0EdA\u002fe2utJnGN7j8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","fillcolor":"rgba(99.0,110.0,250.0,0.2)","hoverinfo":"none","line":{"color":"rgba(255,255,255,0)"},"mode":"lines","name":"x1 HDI","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgcHBgUEAwIBAA=="},"y":{"dtype":"f8","bd ...

# %% [markdown]
# ---
#
# ## 6. Auto-faceting Across Custom Dimensions
#
# When your model includes **custom dimensions** (like `geo` in our example),
# `plot_interactive` **automatically creates subplots** (facets) for each
# dimension value. You've already seen this in all the plots above — each
# subplot corresponds to a different geography (`geo_a` and `geo_b`).
#
# This behavior is controlled by the `auto_facet` parameter, which is
# **enabled by default**. You can also control the faceting layout with
# `facet_col` and `facet_row`:
#
# - `facet_col` — creates side-by-side columns (one per dimension value)
# - `facet_row` — stacks subplots vertically (one per dimension value)
# - `single_dim_facet` — controls the default direction (`"col"` or `"row"`)
#
# ### Q: Compare saturation curves across geos stacked vertically
#
# Using `facet_row="geo"` overrides the default column layout and stacks
# the saturation curves vertically instead.

# %%
mmm.plot_interactive.saturation_curves(
    facet_row="geo",
)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="f442685a-e6bf-4b7e-aa45-9a58047117c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f442685a-e6bf-4b7e-aa45-9a58047117c4")) {                    Plotly.newPlot(                        "f442685a-e6bf-4b7e-aa45-9a58047117c4",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAB+MqffY4hXQH4yp99jiGdA3mW950qmcUB+MqffY4h3QB7\u002fkNd8an1A3mW950qmgUAvTLJjV5eEQH4yp99jiIdAzRicW3B5ikAe\u002f5DXfGqNQLfywqnELZBA3mW950qmkUAG2bcl0R6TQC9MsmNXl5RAVr+sod0PlkB+MqffY4iXQKaloR3qAJlAzRicW3B5mkD2i5aZ9vGbQB7\u002fkNd8ap1ARXKLFQPjnkC38sKpxC2gQEsswMgH6qBA3mW950qmoUByn7oGjmKiQAbZtyXRHqNAmxK1RBTbo0AvTLJjV5ekQMKFr4KaU6VAVr+sod0PpkDq+KnAIMymQH4yp99jiKdAEmyk\u002fqZEqECmpaEd6gCpQDrfnjwtvalAzRicW3B5qkBhUpl6szWrQPaLlpn28atAisWTuDmurEAe\u002f5DXfGqtQLI4jva\u002fJq5ARXKLFQPjrkDZq4g0Rp+vQLfywqnELbBAgY9BOeaLsEBLLMDIB+qwQBXJPlgpSLFA3mW950qmsUCoAjx3bASyQHKfugaOYrJAPTw5lq\u002fAskAG2bcl0R6zQNB1NrXyfLNAmxK1RBTbs0BkrzPUNTm0QC9MsmNXl7RA+Ogw83j1tEDCha+CmlO1QIwiLhK8sbVAVr+sod0PtkAgXCsx\u002f222QOr4qcAgzLZAtJUoUEIqt0B+MqffY4i3QEfPJW+F5rdAEmyk\u002fqZEuEDcCCOOyKK4QKaloR3qALlAcEIgrQtfuUA63548Lb25QAR8HcxOG7pAzRicW3B5ukCYtRrrkde6QGFSmXqzNbtALO8XCtWTu0D2i5aZ9vG7QL8oFSkYULxAisWTuDmuvEBTYhJIWwy9QB7\u002fkNd8ar1A55sPZ57IvUCyOI72vya+QHvVDIbhhL5ARXKLFQPjvkAPDwqlJEG\u002fQNmriDRGn79ApEgHxGf9v0C38sKpxC3AQBxBgnHVXMBAgY9BOeaLwEDl3QAB97rAQEsswMgH6sBAr3p\u002fkBgZwUAVyT5YKUjBQHkX\u002fh86d8FA3mW950qmwUBEtHyvW9XBQKgCPHdsBMJADVH7Pn0zwkA="},"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAAACIX9FcGWEZQKiVvsMJYSlAO3m707MIM0Ahhwthy2A5QAQM3r7DuD9ACbeokUoIQ0AB0OviGzRGQFnevO\u002fRX0lA3ruN1WiLTEBSLt+y3LZPQIc1sdMUcVFAhT0N6qUGU0Dxvb6tH5xUQPPcyjCAMVZAK1ERhsXGV0DWwlzB7VtZQB0Wc\u002ff28FpA4polPt+FXEBvIWGspBpeQCzyPVpFr19APtOHsN+hYEBIcbptCGxhQCV2s\u002fIbNmJATpAkThkAY0CYIXyP\u002f8ljQHHU7MbNk2RArx11BYNdZUCCqeZcHidmQBS07d+e8GZAIkwYogO6Z0CPf923S4NoQCZxpDZ2TGlA5VbLNIIVakBDYK7Jbt5qQCeErg07p2tAcTU4GuZvbEBP\u002fskJbzhtQBwB+\u002ffUAG5ARV+BARfJbkBbhDhENJFvQFKrk++VLHBAWiVDeX6QcEApruJPU\u002fRwQHD0yAQUWHFAQzfuKcC7cUBEFu9RVx9yQLpTDxDZgnJAHYc8+ETmckC7wBCfmklzQF4e1ZnZrHNARVCEfgEQdEDJDs3jEXN0QI+AFGEK1nRAO5F4juo4dUD\u002fN9IEspt1QMmut11g\u002fnVAmZl+M\u002fVgdkDfHT4hcMN2QN3p0MLQJXdAdizXtBaId0C4fLiUQep3QIKxpQBRTHhAgqmal0SueECnAmD5GxB5QInCjMbWcXlANu6HoHTTeUBQEoop9TR6QK+7ngRYlnpA19+l1Zz3ekANNlVBw1h7QL2AOe3KuXtAJ8e3f7MafEDvfw6gfHt8QO2rVvYl3HxAKeKEK688fUABTGrpF519QHCTtdpf\u002fX1A4cDzqoZdfkBqC5EGjL1+QCCa2ZpvHX9AJjb6FTF9f0BU7wAn0Nx\u002fQA3Z7j4mHoBAoGex5dJNgED2uqLgbX2AQOAPDwn3rIBAu3e0OG7cgEAGAcNJ0wuBQC\u002fZ3BYmO4FAEmgWe2ZqgUDsZPZRlJmBQM3kdXevyIFACmMAyLf3gUBCw3MgrSaCQIZNIF6PVYJAYKTIXl6EgkAftaEAGrOCQAqiUiLC4YJAnKf0olYQg0A="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002f6ukTjpq9ARWxtkg8+sEBbW32CraiwQHBKjXJLE7FAhTmdYul9sUCbKK1Sh+ixQLAXvUIlU7JAxgbNMsO9skDb9dwiYSizQPHk7BL\u002fkrNABtT8Ap39s0AcwwzzOmi0QDGyHOPY0rRAR6Es03Y9tUBckDzDFKi1QHF\u002fTLOyErZAh25co1B9tkCcXWyT7ue2QLJMfIOMUrdAxzuMcyq9t0DcKpxjyCe4QPMZrFNmkrhABwm8QwT9uEAe+Mszome5QDPn2yNA0rlASdbrE948ukBexfsDfKe6QHO0C\u002fQZErtAiaMb5Ld8u0CekivUVee7QLSBO8TzUbxAyXBLtJG8vEDfX1ukLye9QPROa5TNkb1ACT57hGv8vUAfLYt0CWe ...

# %% [markdown]
# ### Q: What if I want to have all lines in the same plot?
#
# Setting `auto_facet=False` disables the automatic subplot creation.
# For line-based plots (like saturation and adstock curves), the custom
# dimension is then shown using **line dash styles** instead of separate
# subplots — all curves appear on a single plot, differentiated by dashing.

# %%
mmm.plot_interactive.saturation_curves(
    auto_facet=False,
)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8642e291-248f-440d-a0ee-66489a3c34c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8642e291-248f-440d-a0ee-66489a3c34c5")) {                    Plotly.newPlot(                        "8642e291-248f-440d-a0ee-66489a3c34c5",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1, geo_a","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1, geo_a","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAB+MqffY4hXQH4yp99jiGdA3mW950qmcUB+MqffY4h3QB7\u002fkNd8an1A3mW950qmgUAvTLJjV5eEQH4yp99jiIdAzRicW3B5ikAe\u002f5DXfGqNQLfywqnELZBA3mW950qmkUAG2bcl0R6TQC9MsmNXl5RAVr+sod0PlkB+MqffY4iXQKaloR3qAJlAzRicW3B5mkD2i5aZ9vGbQB7\u002fkNd8ap1ARXKLFQPjnkC38sKpxC2gQEsswMgH6qBA3mW950qmoUByn7oGjmKiQAbZtyXRHqNAmxK1RBTbo0AvTLJjV5ekQMKFr4KaU6VAVr+sod0PpkDq+KnAIMymQH4yp99jiKdAEmyk\u002fqZEqECmpaEd6gCpQDrfnjwtvalAzRicW3B5qkBhUpl6szWrQPaLlpn28atAisWTuDmurEAe\u002f5DXfGqtQLI4jva\u002fJq5ARXKLFQPjrkDZq4g0Rp+vQLfywqnELbBAgY9BOeaLsEBLLMDIB+qwQBXJPlgpSLFA3mW950qmsUCoAjx3bASyQHKfugaOYrJAPTw5lq\u002fAskAG2bcl0R6zQNB1NrXyfLNAmxK1RBTbs0BkrzPUNTm0QC9MsmNXl7RA+Ogw83j1tEDCha+CmlO1QIwiLhK8sbVAVr+sod0PtkAgXCsx\u002f222QOr4qcAgzLZAtJUoUEIqt0B+MqffY4i3QEfPJW+F5rdAEmyk\u002fqZEuEDcCCOOyKK4QKaloR3qALlAcEIgrQtfuUA63548Lb25QAR8HcxOG7pAzRicW3B5ukCYtRrrkde6QGFSmXqzNbtALO8XCtWTu0D2i5aZ9vG7QL8oFSkYULxAisWTuDmuvEBTYhJIWwy9QB7\u002fkNd8ar1A55sPZ57IvUCyOI72vya+QHvVDIbhhL5ARXKLFQPjvkAPDwqlJEG\u002fQNmriDRGn79ApEgHxGf9v0C38sKpxC3AQBxBgnHVXMBAgY9BOeaLwEDl3QAB97rAQEsswMgH6sBAr3p\u002fkBgZwUAVyT5YKUjBQHkX\u002fh86d8FA3mW950qmwUBEtHyvW9XBQKgCPHdsBMJADVH7Pn0zwkA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAADW\u002fDj8SbcYQEVx09I8tyhAi7GMKl2JMkBOgUsuCLc4QImRAeGY5D5ANinfVwSJQkCREDmEqJ9FQEeNDa01tkhAc+x4iqjMS0CNC0vV\u002feJOQILNjiOZ\\u002fSvL9AnlsQCfkQfmBPG1ACz+0duL\u002fbUCOMF+zI8NuQJwtI+1Ehm9AN9FXsaIkcECJncMpEoZwQO0NAoBw53BAcAWuVL1IcUCFRNJI+KlxQJBt6\u002f0gC3JAPAHqFTdsckCBUjQzOs1yQHtyqPgpLnNAvROeCQaPc0DiZOgJzu9zQDrj152BUHRA7yM8aiCxdEAllWUUqhF1QP41J0IecnVAHUbYmXzSdUC761XCxDJ2QIHRBGP2knZA\u002fbrSIxHzdkA2EDitFFN3QG1gOagAs3dAk9tovtQSeECWwueZkHJ4QF7PZ+Uz0nhAq5IsTL4xeUB8yQx6L5F5QFWpcxuH8HlARCNi3cRPekDUHXBt6K56QOalzXnxDXtA2hZEsd9se0DoODfDsst7QDFXpl9qKnxAc0wtNwaJfECAhgX7hed8QJABB13pRX1AvzmpDzCkfUAgFATGWQJ+QCi\u002f0DNmYH5AyYlqDVW+fkAhss8HJhx\u002fQH8rotjYeX9Aj1soNm3Xf0Cc56ZrcRqAQEbz0bkcSYBAPzyxYbh3gEA8N7Q\u002fRKaAQGkrnjDA1IBA1neGESwDgUC+1Ni\u002fhzGBQLWQVRnTX4FAjckR\u002fA2OgUC3oXdGOLyBQHJxRtdR6oFA0POSjVoYgkBicMdIUkaCQKjgo+g4dIJA1RE+TQ6igkA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eSpend=%{x}\u003cbr\u003eResponse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1, geo_b","line":{"color":"#636efa","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1, geo_b","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"...\u002f6ukTjpq9ARWxtkg8+sEBbW32CraiwQHBKjXJLE7FAhTmdYul9sUCbKK1Sh+ixQLAXvUIlU7JAxgbNMsO9skDb9dwiYSizQPHk7BL\u002fkrNABtT8Ap39s0AcwwzzOmi0QDGyHOPY0rRAR6Es03Y9tUBckDzDFKi1QHF\u002fTLOyErZAh25co1B9tkCcXWyT7ue2QLJMfIOMUrdAxzuMcyq9t0DcKpxjyCe4QPMZrFNmkrhABwm8QwT9uEAe+Mszome5QDPn2yNA0rlASdbrE948ukBexfsDfKe6QHO0C\u002fQZErtAiaMb5Ld8u0CekivUVee7QLSBO8TzUbxAyXBLtJG8vEDfX1ukLye9QPROa5TNkb1AC ...

# %% [markdown]
# ### Q: Show adstock curves with geos as columns instead of the default
#
# By passing `single_dim_facet="col"`, the single custom dimension (`geo`)
# is faceted as columns rather than the default rows for this plot type.

# %%
mmm.plot_interactive.adstock_curves(
    single_dim_facet="col",
)
# Out:
# Sampling: []
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="28112ba9-a69c-4c1e-b1bf-68fcd8530c04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("28112ba9-a69c-4c1e-b1bf-68fcd8530c04")) {                    Plotly.newPlot(                        "28112ba9-a69c-4c1e-b1bf-68fcd8530c04",                        [{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"WPewGaZ+5j+wvbZdM5rHP7CrvvpmL7A\u002fuEpibLqAmj\u002fC\u002fzEAP6GIP0tB6AeQLnk\u002fefpziii+az8j9mSLFzpgPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x1\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x1","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"8PvlK5DN5z9g3ppUSIzFP7U2hVAJkqo\u002f9TqRnhQalD\u002fHibX+jJ2BP2zUk879NXE\u002fEMe5FGc\u002fYj\u002fmQG+T3JVUPw=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_a\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"FJRsWBDd5T\u002fxYD1d0yTIP7b8PorVibE\u002fKIVRxwh0nj8JMtsXgvaNP6OAiTjGKoA\u002fAWRRiLO4cj9PYXJvUOlmPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"channel=x2\u003cbr\u003egeo=geo_b\u003cbr\u003eTime Since Exposure=%{x}\u003cbr\u003eEffect Weight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x2","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x2","y":{"dtype":"f8","bdata":"ZOZsfOJk5z8ZOqKdBBHGP+5SWOUTcqw\u002fyzO+zaNslj9XGLdnK0+EP2WhoGbrU3Q\u002ft\u002f2l217sZT8AYqE+OApZPw=="},"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"# ...

# %% [markdown]
# ---
#
# ## 7. Advanced: Filtering & Aggregating with the Data Layer
#
# > **This is an advanced section.** The examples above cover the most common
# > use cases through `mmm.plot_interactive`. This section shows how to work
# > directly with the underlying components for custom data slicing.
#
# Under the hood, `mmm.plot_interactive` is powered by two key classes:
#
# - **`MMMSummaryFactory`** — Takes a data wrapper (from `mmm.data`) and the
#   fitted model, and computes summary statistics like contributions, ROAS,
#   and posterior predictive values. It handles HDI computation, time
#   aggregation, and proper scaling. You can think of it as the "data engine"
#   that turns raw xr.DataTree into plottable DataFrames.
#
# - **`MMMPlotlyFactory`** — Takes an `MMMSummaryFactory` and provides all
#   the interactive plotting methods (`posterior_predictive()`, `roas()`,
#   `contributions()`, `saturation_curves()`, `adstock_curves()`). It reads
#   from the summary factory and creates Plotly figures.
#
# When you call `mmm.plot_interactive`, it automatically creates both of
# these using your full dataset. But you can also create them **manually**
# with filtered or aggregated data — this is the key to custom views.
#
# The workflow is:
#
# 1. **Transform the data** using `mmm.data.filter_dims()`, `mmm.data.filter_dates()`,
#    or `mmm.data.aggregate_dims()`
# 2. **Create a new `MMMSummaryFactory`** with the transformed data
# 3. **Create a new `MMMPlotlyFactory`** with that summary
# 4. **Plot** using the factory's methods
#
# ### Q: Aggregating over geos, how did the ROAS of each channel change year after year?
#
# Here we aggregate both geos into a single "all_geos" label, then plot ROAS.
# This collapses the geo dimension so we get a single aggregated view.

# %%
from pymc_marketing.mmm.plot_interactive import MMMPlotlyFactory
from pymc_marketing.mmm.summary import MMMSummaryFactory

# Aggregate geo_a and geo_b into "all_geos"
agg_data = mmm.data.aggregate_dims(
    dim="geo", values=["geo_a", "geo_b"], new_label="all_geos"
)
agg_summary = MMMSummaryFactory(agg_data, mmm)
agg_factory = MMMPlotlyFactory(summary=agg_summary)

agg_factory.roas(
    frequency="yearly",
    color="channel",
    x="date",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="db9158b4-a84d-4478-9def-ea64ae6271cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("db9158b4-a84d-4478-9def-ea64ae6271cf")) {                    Plotly.newPlot(                        "db9158b4-a84d-4478-9def-ea64ae6271cf",                        [{"alignmentgroup":"True","customdata":[["0.135 HDI: [0.015, 0.272]","all_geos"],["0.134 HDI: [0.016, 0.27]","all_geos"],["0.139 HDI: [0.015, 0.282]","all_geos"],["0.134 HDI: [0.016, 0.266]","all_geos"]],"error_y":{"array":{"dtype":"f8","bdata":"k5Pe9q+NwT+\u002fXKtzOU\u002fBP0\u002fJbSvmQcI\u002fF4QDP+HRwD8="},"arrayminus":{"dtype":"f8","bdata":"Hy8WS5LTvj8iWd2Qm2y+P3PeZoYs+L8\u002fHHJVpgxfvj8="}},"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"bzL6KsVLwT\u002fnyh8\u002fFDbBP+\u002fu1\u002fBF2sE\u002fhzuv2D4ywT8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["0.114 HDI: [0.004, 0.241]","all_geos"],["0.124 HDI: [0.006, 0.248]","all_geos"],["0.123 HDI: [0.006, 0.246]","all_geos"],["0.117 HDI: [0.012, 0.241]","all_geos"]],"error_y":{"array":{"dtype":"f8","bdata":"Diy1k4A5wD\u002fJC7\u002fZf6y\u002fPzf7DzpUfb8\u002fSW3m0te\u002fvz8="},"arrayminus":{"dtype":"f8","bdata":"HurWDyX+uz8OyHUj2DO+PxiAEA1lHL4\u002frH7Ph5jPuj8="}},"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"sYwKN3EfvT+hKIn5wrS\u002fPxMTZN5Enb8\u002f4Qsbkj\u002fbvT8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"su ...

# %% [markdown]
# ### Q: Filtering to only one geo, what was the yearly ROAS?
#
# You can filter the data to a single geography and create a dedicated factory.

# %%
filtered_data_geo_a = mmm.data.filter_dims(geo="geo_a")
filtered_summary_geo_a = MMMSummaryFactory(
    filtered_data_geo_a, mmm, validate_data=False
)
filtered_factory_geo_a = MMMPlotlyFactory(summary=filtered_summary_geo_a)

filtered_factory_geo_a.roas(
    frequency="yearly",
    color="channel",
    x="date",
    title="ROAS for geo_a (yearly)",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="27339500-4ecc-44ec-ba9f-516cf3c8575f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("27339500-4ecc-44ec-ba9f-516cf3c8575f")) {                    Plotly.newPlot(                        "27339500-4ecc-44ec-ba9f-516cf3c8575f",                        [{"alignmentgroup":"True","customdata":[["0.064 HDI: [0.0, 0.133]"],["0.064 HDI: [0.0, 0.134]"],["0.067 HDI: [0.0, 0.139]"],["0.065 HDI: [0.0, 0.136]"]],"error_y":{"array":{"dtype":"f8","bdata":"jBo1okTSsT9dJOn8Q+mxP294SdE6mbI\u002fWDcq5Qgisj8="},"arrayminus":{"dtype":"f8","bdata":"NTqhp8hIsD8cNrR+8FqwP2Dc7u1L97A\u002fWKFhSBGFsD8="}},"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"zEKcsP5ZsD\u002fdW2lUP3awP8tfJcCwCbE\u002fyIUcvcaWsD8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["nan HDI: [nan, nan]"],["0.074 HDI: [0.002, 0.156]"],["0.074 HDI: [0.002, 0.156]"],["0.07 HDI: [0.002, 0.147]"]],"error_y":{"array":{"dtype":"f8","bdata":"\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f3\u002fg\u002fxB5V\u002fq0PwlgXdos+7Q\u002f\u002fwNLEPuhsz8="},"arrayminus":{"dtype":"f8","bdata":"AAAAAAAA+H9itFPSeZuyP5bz7PhGmbI\u002fWle2\u002fbtVsT8="}},"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2022","2023","2024","2025"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H+yYq0o+A2zPxMPgSzEC7M\u002fzcVdM8zqsT8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111 ...

# %% [markdown]
# ### Q: How did the ROAS change quarter after quarter starting 2024?
#
# Filter by date range and then view quarterly ROAS.

# %%
filtered_data_2024 = mmm.data.filter_dates(start_date="2024-01-01")
filtered_summary_2024 = MMMSummaryFactory(filtered_data_2024, mmm)
filtered_factory_2024 = MMMPlotlyFactory(summary=filtered_summary_2024)

filtered_factory_2024.roas(
    frequency="quarterly",
    color="channel",
    x="date",
    hdi_prob=None,
    title="ROAS from 2024 onwards (quarterly)",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="06e4c363-b9d3-4f2b-9885-dc1ed680f38a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("06e4c363-b9d3-4f2b-9885-dc1ed680f38a")) {                    Plotly.newPlot(                        "06e4c363-b9d3-4f2b-9885-dc1ed680f38a",                        [{"alignmentgroup":"True","customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":true,"textposition":"auto","x":["2024-Q1","2024-Q2","2024-Q3","2024-Q4","2025-Q1","2025-Q2"],"xaxis":"x","y":{"dtype":"f8","bdata":"\u002fljYReyvsT+asoTVOyywP4DIWUvJmbE\u002fQZEPw\u002fSwsD\u002feiOQ++VyuPyAUvr5Q8rM\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_b"],["geo_b"],["geo_b"],["geo_b"],["geo_b"],["geo_b"]],"hovertemplate":"channel=x1\u003cbr\u003eROAS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"x1","offsetgroup":"x1","orientation":"v","showlegend":false,"textposition":"auto","x":["2024-Q1","2024-Q2","2024-Q3","2024-Q4","2025-Q1","2025-Q2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"rhbxTBV7sT+3A7Hm3xixPzlPf+vUDrI\u002fjhVG+xw0sT8JH+rJ7VGwPxqylwLsj7Q\u002f"},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"],["geo_a"]],"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":true,"textposition":"auto","x":["2024-Q1","2024-Q2","2024-Q3","2024-Q4","2025-Q1","2025-Q2"],"xaxis":"x","y":{"dtype":"f8","bdata":"Wx\u002fTUFVEsT\u002f1BFFoD52yP03GCbcp47M\u002fAAAAAAAA+H8AAAAAAAD4f83FXTPM6rE\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["geo_b"],["geo_b"],["geo_b"],["geo_b"],["geo_b"],["geo_b"]],"hovertemplate":"channel=x2\u003cbr\u003eROAS=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"x2","offsetgroup":"x2","orientation":"v","showlegend":false,"textposition":"auto","x":["2024-Q1","2024-Q2","2024-Q3","2024-Q4","2025-Q1","2025-Q2"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAA+H9JMu1X3w+pPzsplebHyKk\u002fv3jleicRsD8AAAAAAAD4fz0vWMVw9aY\u002f"},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555 ...

# %% [markdown]
# ---
#
# ## Summary
#
# The `plot_interactive` module provides a rich set of interactive visualizations for
# exploring MMM results:
#
# | Method | What It Shows | Key Parameters |
# |--------|--------------|----------------|
# | `posterior_predictive()` | Actual vs predicted with HDI band | `hdi_prob`, `frequency` |
# | `contributions()` | Channel/control/seasonality contributions | `component`, `frequency`, `color`, `x` |
# | `roas()` | Return on Ad Spend | `frequency`, `color`, `x` |
# | `saturation_curves()` | Diminishing returns curves | `hdi_prob`, `max_value`, `original_scale` |
# | `adstock_curves()` | Carryover effect curves | `hdi_prob`, `amount` |
#
# **Key features:**
# - **Auto-faceting**: Custom dimensions (e.g., geo) automatically create subplots
# - **Facet control**: Use `facet_col`, `facet_row`, and `auto_facet` to customize layout
# - **Filtering**: Use `mmm.data.filter_dims()` or `filter_dates()` to focus on subsets
# - **Aggregating**: Use `mmm.data.aggregate_dims()` to combine dimensions
# - **Error bars**: Control with `hdi_prob` (set to `None` to remove)
# - **Customizable**: All Plotly Express kwargs (title, height, width, colors, etc.) are supported

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w -p pymc_marketing,pytensor
# Out:
# Last updated: Tue, 30 Jun 2026
#
# Python implementation: CPython
# Python version       : 3.14.2
# IPython version      : 9.14.0
#
# pymc_marketing: 1.0.0.dev0
# pytensor      : 3.0.5
#
# numpy         : 2.4.6
# pandas        : 2.3.3
# plotly        : 6.7.0
# pymc_extras   : 0.12.2.dev1+gee8cc37df
# pymc_marketing: 1.0.0.dev0
#
# Watermark: 2.6.0
